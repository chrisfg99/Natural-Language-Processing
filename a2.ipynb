# %% [markdown]
# # NLE Assessed Coursework 2
#
# For this assessment, you are expected to complete and submit this notebook file.  When answers require code, you may import and use library functions (unless explicitly told otherwise).  All of your own code should be included in the notebook rather than imported from elsewhere.  Written answers should also be included in the notebook.  You should insert as many extra cells as you want and change the type between code and markdown as appropriate.
#
# In order to avoid misconduct, you should not talk about these coursework questions with your peers.  If you are not sure what a question is asking you to do or have any other questions, please ask me or one of the Teaching Assistants.
#
# Marking guidelines are provided as a separate document.
#
# In order to provide unique datasets for analysis by different students, you must enter your candidate number in the following cell.

# %%
candidateno=184521 #this MUST be updated to your candidate number so that you get a unique data sample
# Out:
#   File "<ipython-input-1-b71e1386593e>", line 2
#     conda install -c conda-forge/label/gcc7 spacy
#                 ^
# SyntaxError: invalid syntax

# %%
#preliminary imports
import sys
sys.path.append('resources')

import nltk
import re
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from itertools import zip_longest
from nltk.tokenize import word_tokenize

from sussex_nltk.corpus_readers import AmazonReviewCorpusReader
import random
from nltk.corpus import stopwords
nltk.download('semcor')

from nltk.corpus import wordnet as wn
from nltk.corpus import wordnet_ic as wn_ic
# Out:
# Sussex NLTK root directory is resources
# [nltk_data] Downloading package semcor to
# [nltk_data]     C:\Users\chris\AppData\Roaming\nltk_data...
# [nltk_data]   Package semcor is already up-to-date!

# %% [markdown]
# ## Question 1: Document Similarity (25 marks)
# The objective of this question is to investigate whether incorporating lexical knowledge from WordNet might improve document similarity methods.  For example, knowing that both *tiger* and *leopard* are hyponyms of *big_cat* should increase the similarity between a document mentioning a *tiger* and a document mentioning a *leopard*.
#
# The code below will generate two document collections, both in bag-of-words format, one from the Medline Corpus and one from the Wall Street Journal corpus.
#
# In this question, there are marks available for the quality of your code and the quality of your explanations.

# %%
from sussex_nltk.corpus_readers import MedlineCorpusReader
from sussex_nltk.corpus_readers import WSJCorpusReader
from nltk.stem.wordnet import WordNetLemmatizer

def normalise(tokenlist):
    tokenlist=[token.lower() for token in tokenlist]
    tokenlist=["NUM" if token.isdigit() else token for token in tokenlist]
    tokenlist=["Nth" if (token.endswith(("nd","st","th")) and token[:-2].isdigit()) else token for token in tokenlist]
    tokenlist=["NUM" if re.search("^[+-]?[0-9]+\.[0-9]",token) else token for token in tokenlist]
    return tokenlist

def filter_stopwords(tokenlist):
    stop = stopwords.words('english')
    return [w for w in tokenlist if w.isalpha() and w not in stop]

def stem(tokenlist):
    st=WordNetLemmatizer()
    return [st.lemmatize(token) for token in tokenlist]

   
def make_bow(somestring):
    rep=word_tokenize(somestring)  #step 1
    rep=normalise(rep)   #step 2
    rep=stem(rep)   #step 3
    rep=filter_stopwords(rep)  #step 4
    dict_rep={}
    for token in rep:
        dict_rep[token]=dict_rep.get(token,0)+1  #step 5
    return(dict_rep)

wsj=WSJCorpusReader()
medline=MedlineCorpusReader()

collectionsize=50
collections={"wsj":[],"medline":[]}

for key in collections.keys():
    if key=="wsj":
        generator=wsj.raw()
    else:
        generator=medline.raw()
    while len(collections[key])<collectionsize:
        collections[key].append(next(generator))

bow_collections={key:[make_bow(doc) for doc in collection] for key,collection in collections.items()}

# %% [markdown]
# a). For each step in the `make_bow()` function, **explain** what it does and why it is applicable when creating document representations for document similarity methods. \[8 marks\]

# %% [markdown]
# Step 1: rep=word_tokenize(somestring)
# This step tokenises the input sting by removing all punctuation from the input string and then assigns this now tokenised string to the variable 'rep'.
#
# Step 2: rep=normalise(rep)
# This step normalises the value of the variable 'rep', which is the tokenised input string. Normalising the string equates to putting everything into lowercase before scanning through and changes ints to num strings and nth's to strings aswell. This leaves 'rep' with the value of s sting with no ints and all in lowercase.
#
# Step 3: rep=stem(rep)
# The 'stem' function removes any tenses of the words in the given string to give the default present tense of the word, for example if given "streamed" it would return "stream". This stem'd sting is then passed as the value for 'rep'.
#
# Step 4: rep=filter_stopwords(rep)
# This step makes use of the "filter_stopwords" which takes a string and removes any stop words, such as 'the', 'is' and 'are', which have to be removed before the string can be processed by a classifier. This step tehrfore assigns a normalised, tokesnised and present tense string without any stop words to the variable of 'rep'.
#
# Step 5: dict_rep[token]=dict_rep.get(token,0)+1
# This step takes place within a for loop where for each token in the variable 'rep' step 5 is executed, with 'token' being a key in a dictionary that is taken from the string 'rep' and passed to the new dictionary of 'dict_rep'. This line and for loop is therefore building a dictionary of the collection of the input string given at the start of the function 'make_bow'.

# %% [markdown]
# b). Apply a TF-IDF weighting to the representations and then compute:
# * the average cosine similarity of medline documents to each other,
# * the average cosine similarity of WSJ documents to each other,
# * the average cosine similarity of medline documents to WSJ documents
# \[8 marks\]

# %%
import math
#assumptions;Comparing a document against itself results in a simalarity of 1 so this may cause results to be incorrect
#            It would be easy enough to remove the similarites equal to 1 but there may be some which do have a similarity
#            of 1 that aren't the same document which could make the values even more incorrect
#            Don't need to compare all documents neccassariy and could do a sample if there was enough variety
#           

#tf function
def get_tf(value,N):
    #return the value divided by the length
    return value/N

#idf function
def get_idf(value,N):
    #return the value divided by the length logged
    return math.log(N/value)
        
#tfidf function
def get_tfidf(doclist):
    #initialise iteratiors
    y=0
    x=0
    #initialise sets
    tfidf={}
    tfidf_temp={}
    #for loop to iterate through the doc list
    for z in range (len(doclist)):
        #length of current doc set to N
        N=len(doclist[x])
        doc=doclist[x]
        x+=1
        #for loop to iterate through each key and value in a doc
        for k,v in doc.items(): 
            #temporary set is filled with tf and idf values if each item
            tfidf_temp[k]=get_tf(doc[k],N)*get_idf(doc[k],N)
            y+=1
        #temporary set is copied into actual set
        tfidf[x]=tfidf_temp
        #temporary set is cleared
        tfidf_temp={}
    #return tfidf values in the set
    return tfidf

#comparison functions
#dot product function
def dot(docA,docB):
    #initialise my sum
    s= 0
    #for loop to iterate through each key and value of a doc
    for (k,v) in docA.items():
        #add the current sum to itself with docA's value multiplied by docB's
        s+=(v*docB.get(k,0))
    #sum is returned
    return s

#function for cosine sim
def cos_sim(docA,docB):
    #variable is set to dot product of docA and docB
    sim=dot(docA,docB)
    #denominator is set to the square root of the dot product of A and A multiplied by the dot product of B and B
    denominator=math.sqrt(dot(docA,docA)*dot(docB,docB))
    #the sim var is then divided by the denominator
    sim=sim/denominator
    #return the final similarity
    return sim

# %%
#get tfidf for wsj
wsj_tfidf=get_tfidf(bow_collections['wsj'])

#get tfidf for medline
med_tfidf=get_tfidf(bow_collections['medline'])

#comparison function
def compare(colA,colB):
    #initialise the similarity set 
    sims=[]
    #initialise the sum variable
    sum=0
    #iterate through the given collections of tfidf values
    for kA in colA.keys():
        for kB in colB.keys():
            #compare the currently selected tfidf values using the cos_sim function
            sims.append(cos_sim(colA[kA],colB[kB]))
    #iterate through each similarity
    for x in range(len(sims)):
        #add all similarities together
        sum=sum+sims[x]
    #divde the total by the number of values giving the average value
    sum=sum/len(sims)
    #return the average value
    return sum
    
#output wsj to wsj
print("Avr similarity for WSJ to WSJ =",compare(wsj_tfidf,wsj_tfidf))
#output med to med
print("Avr similarity for Medline to Medline =",compare(med_tfidf,med_tfidf))
#output wsj to med
print("Avr similarity for Medline to WSJ =",compare(wsj_tfidf,med_tfidf))
# Out:
# Avr similarity for WSJ to WSJ = 0.07721004853891898
# Avr similarity for Medline to Medline = 0.11859917330434114
# Avr similarity for Medline to WSJ = 0.03754868388759906

# %% [markdown]
# assumptions;Comparing a document against itself results in a simalarity of 1 so this may cause results to be incorrect
#            It would be easy enough to remove the similarites equal to 1 but there may be some which do have a similarity
#            of 1 that aren't the same document which could make the values even more incorrect
#            Don't need to compare all documents neccassariy and could do a sample if there was enough variety
#
# import maths library
#
# tf function:returns the value divided by the length
# idf function:returns the value divided by the length logged
#
# tfidf function:initialises iterators and sets then uses a for loop to iterate through the doc list.
#                Length of current doc set to N and another for loop  uses this to iterate through each key and value in a doc.
#                Temporary set is filled with tf and idf values of each item and temporary set is copied into actual set before                   being cleared.
#                Return all tfidf values
#
# Comparison functions
# dot product function:initialise my sum
#                      For loop used to iterate through each key and value of a doc
#                      Add current sum to itself with docA's value multiplied by docB's and return it
# function for cosine sim: a variable is set to dot product of docA and docB
#                          Denominator becomes the square root of the dot product of A & A multiplied by the dot product of B & B
#                          The sim variable is then divided by the denominator before returning the final similarity
#
# get tfidf is called for medline and wsj and stored in variables
#
# comparison function:initialise the similarity set and sum variable
#                     iterate through the given collections of tfidf values
#                     compare the currently selected tfidf values using cos_sim function
#                     iterate through each similarity and add them together
#                     divide the total by the number of values giving the average value which is returned
#
# output similarities of wsj to wsj, med to med and wsj to med

# %% [markdown]
# c). Expand the document representations by adding **synonyms** and **hypernyms** for each **noun** in the document.  For example, 2 occurrences of the word *tiger* should add 2 occurrences of each of the following **lemma_names** found in the WordNet hypernym hierarchy above *tiger*:
# * \['tiger', 'Panthera_tigris'\]
# * \['big_cat', 'cat'\]
# * \['feline', 'felid'\]
# * \['carnivore'\]
# * \['placental', 'placental_mammal', 'eutherian', 'eutherian_mammal'\]
# * \['mammal', 'mammalian'\]
# * \['vertebrate', 'craniate'\]
# * \['chordate'\]
# * \['animal', 'animate_being', 'beast', 'brute', 'creature', 'fauna'\]
# * \['organism', 'being'\]
# * \['living_thing', 'animate_thing'\]
# * \['whole', 'unit'\]
# * \['object', 'physical_object'\]
# * \['physical_entity'\]
# * \['entity'\]
#
# Recompute the similarities calculated in part b).  Discuss your results. \[9 marks\]

# %%
#function to get the nouns of a document
def getNouns(doc):
    #initialise noun array
    sym={}
    nouns=[]
    #iterate through each sentence in a document
    for k in range(len(doc)):
        sentences=doc[k]
        #iterate through each word in the sentence
        for  w,v in sentences.items():
            word=w
            #add them to nouns array if a noun
            if(len(wn.synsets(word))>0):
                temp = wn.synsets(word)[0].pos()
                if (temp=='n'):
                    nouns.append(word)
    return nouns
                    
#function to get hypernyms of a given noun
def getHypernyms(n):
    #initialises hypernym array
    hyp=[]
    #makes sure it only includes words with hypernyms
    if(len(wn.synsets(n))>1):
        #hypernyms are put into a variable
        hypernyms=wn.synsets(n)[1].hypernym_paths()
        for h in hypernyms[0]:
            #hypernym names are extarcted and returned
            hyp.append(h.lemma_names())
    return hyp

#function to get symonyms of a given noun
def getSymonyms(n):
    #initialises symonym set
    sym=[]
    #gets the synset of the word
    synset=wn.synsets(n)
    #makes sure it only includes words with symonyms
    if(len(synset)>1):
        for s in synset:
            for w in s.lemmas():
                #symonym's names are put into a variable
                sym.append(s.lemma_names())
    return sym

#pair a word with its symonyms
def pair(w,s,h):
    #put symonyms in a set
    syms={'symonyms':s}
    #put hypernyms in a set
    hyp={'hypernyms':h}
    #syms and hyps combined
    symHyp=(syms,hyp)
    #syms and hypes added to set with key of the word
    newSet={w:symHyp}
    #return the set
    return newSet
    
def getSymHyp(nouns):
    #initialise new doc dictionary
    newDoc=[]
    #iterate through each word in the nouns array and get their symonyms and hypernyms
    i=0
    for i in range(len(nouns)):
        word=nouns[i]
        s=getSymonyms(word)
        h=getHypernyms(word)
        #put the word and its symonyms and hypernyms into the pair function and add this set to the newDoc variable
        newDoc.append(pair(word,s,h))
    #return the completed newDoc
    return newDoc

#fucntion to output a word and symonyms and hypernyms
def outputs(newDoc):
    i=0
    #iterate through each word in a doc and output its symonyms and hypernyms
    for w in newDoc:
        for x in newDoc[i]:
            print('The symonyms and hypernyms for:',w)
        i+=1
    return newDoc

# %% [markdown]
# Assumptions:
# There is no need to compute the tfidf values for the new collections ass there will only be a slight increase in their similarities. This increase shall be due to multiple words having the same hypernyms and symonyms making them seem more similar than they actually are. This increase is true as it would now take in to account them containing sentences with similar meanings instead of just if they contain the same words and cutting down to just the nouns decreases the amount of comparisons needed and therefore would increase similarity. However I don't think the similarity needs to be documented and as it will not increase by much.

# %%
#call the above functions to get the needed answer
med_nouns=getNouns(bow_collections['medline'])
newDoc=outputs(getSymHyp(med_nouns))
wsj_nouns=getNouns(bow_collections['wsj'])
newDoc=outputs(getSymHyp(wsj_nouns))
# Out:
# The symonyms and hypernyms for: {'case': ({'symonyms': [['case', 'instance', 'example'], ['case', 'instance', 'example'], ['case', 'instance', 'example'], ['event', 'case'], ['event', 'case'], ['lawsuit', 'suit', 'case', 'cause', 'causa'], ['lawsuit', 'suit', 'case', 'cause', 'causa'], ['lawsuit', 'suit', 'case', 'cause', 'causa'], ['lawsuit', 'suit', 'case', 'cause', 'causa'], ['lawsuit', 'suit', 'case', 'cause', 'causa'], ['case'], ['case'], ['case'], ['subject', 'case', 'guinea_pig'], ['subject', 'case', 'guinea_pig'], ['subject', 'case', 'guinea_pig'], ['case'], ['case'], ['case', 'caseful'], ['case', 'caseful'], ['case', 'grammatical_case'], ['case', 'grammatical_case'], ['case'], ['character', 'eccentric', 'type', 'case'], ['character', 'eccentric', 'type', 'case'], ['character', 'eccentric', 'type', 'case'], ['character', 'eccentric', 'type', 'case'], ['font', 'fount', 'typeface', 'face', 'case'], ['font', 'fount', 'typeface', 'face', 'case'], ['font', 'fount', 'typeface', 'face', 'case'], ['font', 'fount', 'typeface', 'face', 'case'], ['font', 'fount', 'typeface', 'face', 'case'], ['sheath', 'case'], ['sheath', 'case'], ['shell', 'case', 'casing'], ['shell', 'case', 'casing'], ['shell', 'case', 'casing'], ['casing', 'case'], ['casing', 'case'], ['case', "compositor's_case", "typesetter's_case"], ['case', "compositor's_case", "typesetter's_case"], ['case', "compositor's_case", "typesetter's_case"], ['case', 'pillowcase', 'slip', 'pillow_slip'], ['case', 'pillowcase', 'slip', 'pillow_slip'], ['case', 'pillowcase', 'slip', 'pillow_slip'], ['case', 'pillowcase', 'slip', 'pillow_slip'], ['case', 'display_case', 'showcase', 'vitrine'], ['case', 'display_case', 'showcase', 'vitrine'], ['case', 'display_case', 'showcase', 'vitrine'], ['case', 'display_case', 'showcase', 'vitrine'], ['case'], ['encase', 'incase', 'case'], ['encase', 'incase', 'case'], ['encase', 'incase', 'case']]}, {'hypernyms': [['entity'], ['abstraction', 'abstract_entity'], ['attribute'], ['state'], ['condition', 'status'], ['circumstance'], ['event', 'case']]})}
# The symonyms and hypernyms for: {'organ': ({'symonyms': [['organ'], ['organ'], ['electric_organ', 'electronic_organ', 'Hammond_organ', 'organ'], ['electric_organ', 'electronic_organ', 'Hammond_organ', 'organ'], ['electric_organ', 'electronic_organ', 'Hammond_organ', 'organ'], ['electric_organ', 'electronic_organ', 'Hammond_organ', 'organ'], ['organ'], ['organ', 'pipe_organ'], ['organ', 'pipe_organ'], ['harmonium', 'organ', 'reed_organ'], ['harmonium', 'organ', 'reed_organ'], ['harmonium', 'organ', 'reed_organ']]}, {'hypernyms': [['entity'], ['abstraction', 'abstract_entity'], ['group', 'grouping'], ['social_group'], ['organization', 'organisation'], ['unit', 'social_unit'], ['administrative_unit', 'administrative_body'], ['agency', 'federal_agency', 'government_agency', 'bureau', 'office', 'authority'], ['organ']]})}
# The symonyms and hypernyms for: {'transplantation': ({'symonyms': [['transplant', 'transplantation', 'organ_transplant'], ['transplant', 'transplantation', 'organ_transplant'], ['transplant', 'transplantation', 'organ_transplant'], ['transplant', 'transplantation', 'transplanting'], ['transplant', 'transplantation', 'transplanting'], ['transplant', 'transplantation', 'transplanting']]}, {'hypernyms': [['entity'], ['abstraction', 'abstract_entity'], ['psychological_feature'], ['event'], ['act', 'deed', 'human_action', 'human_activity'], ['action'], ['change'], ['movement'], ['transplant', 'transplantation', 'transplanting']]})}
# The symonyms and hypernyms for: {'section': ({'symonyms': [['section', 'subdivision'], ['section', 'subdivision'], ['section'], ['section'], ['section', 'segment'], ['section', 'segment'], ['section'], ['part', 'section', 'division'], ['part', 'section', 'division'], ['part', 'section', 'division'], ['section'], ['section', 'plane_section'], ['section', 'plane_section'], ['section', 'discussion_section'], ['section', 'discussion_section'], ['section'], ['section'], ['department', 'section'], ['department', 'section'], ['section'], ['incision', 'section', 'surgical_incision'], ['incision', 'section', 'surgical_incision'], ['incision', 'section', 'surgical_incision'], ['segment', 'section'], ['segment', 'section']]}, {'hypernyms': [['entity'], ['physical_entity'], ['thing'], ['part', 'piece'], ['slice'], ['section']]})}
# The symonyms and hypernyms for: {'ovary': ({'symonyms': [['ovary'], ['ovary']]}, {'hypernyms': [['entity'], ['physical_entity'], ['thing'], ['part', 'piece'], ['body_part'], ['organ'], ['reproductive_organ', 'sex_organ'], ['female_internal_reproductive_organ'], ['ovary']]})}
# The symonyms and hypernyms for: {'woman': ({'symonyms': [['woman', 'adult_female'], ['woman', 'adult_female'], ['woman'], ['charwoman', 'char', 'cleaning_woman', 'cleaning_lady', 'woman'], ['charwoman', 'char', 'cleaning_woman', 'cleaning_lady', 'woman'], ['charwoman', 'char', 'cleaning_woman', 'cleaning_lady', 'woman'], ['charwoman', 'char', 'cleaning_woman', 'cleaning_lady', 'woman'], ['charwoman', 'char', 'cleaning_woman', 'cleaning_lady', 'woman'], ['womanhood', 'woman', 'fair_sex'], ['womanhood', 'woman', 'fair_sex'], ['womanhood', 'woman', 'fair_sex']]}, {'hypernyms': [['entity'], ['physical_entity'], ['causal_agent', 'cause', 'causal_agency'], ['person', 'individual', 'someone', 'somebody', 'mortal', 'soul'], ['female', 'female_person'], ['woman']]})}
# The symonyms and hypernyms for: {'oophorectomy': ({'symonyms': []}, {'hypernyms': []})}
# The symonyms and hypernyms for: {'paper': ({'symonyms': [['paper'], ['composition', 'paper', 'report', 'theme'], ['composition', 'paper', 'report', 'theme'], ['composition', 'paper', 'report', 'theme'], ['composition', 'paper', 'report', 'theme'], ['newspaper', 'paper'], ['newspaper', 'paper'], ['paper'], ['paper'], ['newspaper', 'paper', 'newspaper_publisher'], ['newspaper', 'paper', 'newspaper_publisher'], ['newspaper', 'paper', 'newspaper_publisher'], ['newspaper', 'paper'], ['newspaper', 'paper'], ['paper'], ['wallpaper', 'paper'], ['wallpaper', 'paper']]}, {'hypernyms': [['entity'], ['abstraction', 'abstract_entity'], ['communication'], ['written_communication', 'written_language', 'black_and_white'], ['writing', 'written_material', 'piece_of_writing'], ['essay'], ['composition', 'paper', 'report', 'theme']]})}
# The symonyms and hypernyms for: {'concentrate': ({'symonyms': [['dressed_ore', 'concentrate'], ['dressed_ore', 'concentrate'], ['concentrate'], ['concentrate'], ['concentrate'], ['concentrate', 'focus', 'center', 'centre', 'pore', 'rivet'], ['concentrate', 'focus', 'center', 'centre', 'pore', 'rivet'], ['concentrate', 'focus', 'center', 'centre', 'pore', 'rivet'], ['concentrate', 'focus', 'center', 'centre', 'pore', 'rivet'], ['concentrate', 'focus', 'center', 'centre', 'pore', 'rivet'], ['concentrate', 'focus', 'center', 'centre', 'pore', 'rivet'], ['centralize', 'centralise', 'concentrate'], ['centralize', 'centralise', 'concentrate'], ['centralize', 'centralise', 'concentrate'], ['digest', 'condense', 'concentrate'], ['digest', 'condense', 'concentrate'], ['digest', 'condense', 'concentrate'], ['concentrate'], ['condense', 'concentrate', 'contract'], ['condense', 'concentrate', 'contract'], ['condense', 'concentrate', 'contract'], ['boil_down', 'reduce', 'decoct', 'concentrate'], ['boil_down', 'reduce', 'decoct', 'concentrate'], ['boil_down', 'reduce', 'decoct', 'concentrate'], ['boil_down', 'reduce', 'decoct', 'concentrate'], ['reduce', 'boil_down', 'concentrate'], ['reduce', 'boil_down', 'concentrate'], ['reduce', 'boil_down', 'concentrate']]}, {'hypernyms': [['entity'], ['physical_entity'], ['matter'], ['substance'], ['food', 'nutrient'], ['foodstuff', 'food_product'], ['concentrate']]})}
# The symonyms and hypernyms for: {'technique': ({'symonyms': [['technique'], ['proficiency', 'technique'], ['proficiency', 'technique']]}, {'hypernyms': [['entity'], ['abstraction', 'abstract_entity'], ['attribute'], ['state'], ['skillfulness'], ['proficiency', 'technique']]})}
# The symonyms and hypernyms for: {'outcome': ({'symonyms': [['result', 'resultant', 'final_result', 'outcome', 'termination'], ['result', 'resultant', 'final_result', 'outcome', 'termination'], ['result', 'resultant', 'final_result', 'outcome', 'termination'], ['result', 'resultant', 'final_result', 'outcome', 'termination'], ['result', 'resultant', 'final_result', 'outcome', 'termination'], ['consequence', 'effect', 'outcome', 'result', 'event', 'issue', 'upshot'], ['consequence', 'effect', 'outcome', 'result', 'event', 'issue', 'upshot'], ['consequence', 'effect', 'outcome', 'result', 'event', 'issue', 'upshot'], ['consequence', 'effect', 'outcome', 'result', 'event', 'issue', 'upshot'], ['consequence', 'effect', 'outcome', 'result', 'event', 'issue', 'upshot'], ['consequence', 'effect', 'outcome', 'result', 'event', 'issue', 'upshot'], ['consequence', 'effect', 'outcome', 'result', 'event', 'issue', 'upshot']]}, {'hypernyms': [['entity'], ['physical_entity'], ['process', 'physical_process'], ['phenomenon'], ['consequence', 'effect', 'outcome', 'result', 'event', 'issue', 'upshot']]})}
# The symonyms and hypernyms for: {'preliminary': ({'symonyms': [['preliminary', 'prelim'], ['preliminary', 'prelim'], ['preliminary', 'overture', 'prelude'], ['preliminary', 'overture', 'prelude'], ['preliminary', 'overture', 'prelude'], ['preliminary']]}, {'hypernyms': [['entity'], ['abstraction', 'abstract_entity'], ['psychological_feature'], ['event'], ['happening', 'occurrence', 'occurrent', 'natural_event'], ['beginning'], ['origin', 'origination', 'inception'], ['preliminary', 'overture', 'prelude']]})}
# The symonyms and hypernyms for: {'time': ({'symonyms': [['time', 'clip'], ['time', 'clip'], ['time'], ['time'], ['time'], ['time'], ['time'], ['clock_time', 'time'], ['clock_time', 'time'], ['fourth_dimension', 'time'], ['fourth_dimension', 'time'], ['meter', 'metre', 'time'], ['meter', 'metre', 'time'], ['meter', 'metre', 'time'], ['prison_term', 'sentence', 'time'], ['prison_term', 'sentence', 'time'], ['prison_term', 'sentence', 'time'], ['clock', 'time'], ['clock', 'time'], ['time'], ['time'], ['time'], ['time']]}, {'hypernyms': [['entity'], ['abstraction', 'abstract_entity'], ['measure', 'quantity', 'amount'], ['fundamental_quantity', 'fundamental_measure'], ['time_period', 'period_of_time', 'period'], ['time']]})}
# The symonyms and hypernyms for: {'publication': ({'symonyms': [['publication'], ['issue', 'publication'], ['issue', 'publication'], ['publication'], ['publication', 'publishing'], ['publication', 'publishing']]}, {'hypernyms': [['entity'], ['abstraction', 'abstract_entity'], ['psychological_feature'], ['event'], ['act', 'deed', 'human_action', 'human_activity'], ['group_action'], ['transaction', 'dealing', 'dealings'], ['commerce', 'commercialism', 'mercantilism'], ['commercial_enterprise', 'business_enterprise', 'business'], ['printing'], ['issue', 'publication']]})}
# The symonyms and hypernyms for: {'surgeon': ({'symonyms': []}, {'hypernyms': []})}
# The symonyms and hypernyms for: {'found': ({'symonyms': [['found'], ['establish', 'set_up', 'found', 'launch'], ['establish', 'set_up', 'found', 'launch'], ['establish', 'set_up', 'found', 'launch'], ['establish', 'set_up', 'found', 'launch'], ['establish', 'found', 'plant', 'constitute', 'institute'], ['establish', 'found', 'plant', 'constitute', 'institute'], ['establish', 'found', 'plant', 'constitute', 'institute'], ['establish', 'found', 'plant', 'constitute', 'institute'], ['establish', 'found', 'plant', 'constitute', 'institute'], ['establish', 'base', 'ground', 'found'], ['establish', 'base', 'ground', 'found'], ['establish', 'base', 'ground', 'found'], ['establish', 'base', 'ground', 'found'], ['find', 'happen', 'chance', 'bump', 'encounter'], ['find', 'happen', 'chance', 'bump', 'encounter'], ['find', 'happen', 'chance', 'bump', 'encounter'], ['find', 'happen', 'chance', 'bump', 'encounter'], ['find', 'happen', 'chance', 'bump', 'encounter'], ['detect', 'observe', 'find', 'discover', 'notice'], ['detect', 'observe', 'find', 'discover', 'notice'], ['detect', 'observe', 'find', 'discover', 'notice'], ['detect', 'observe', 'find', 'discover', 'notice'], ['detect', 'observe', 'find', 'discover', 'notice'], ['find', 'regain'], ['find', 'regain'], ['determine', 'find', 'find_out', 'ascertain'], ['determine', 'find', 'find_out', 'ascertain'], ['determine', 'find', 'find_out', 'ascertain'], ['determine', 'find', 'find_out', 'ascertain'], ['find', 'feel'], ['find', 'feel'], ['witness', 'find', 'see'], ['witness', 'find', 'see'], ['witness', 'find', 'see'], ['line_up', 'get_hold', 'come_up', 'find'], ['line_up', 'get_hold', 'come_up', 'find'], ['line_up', 'get_hold', 'come_up', 'find'], ['line_up', 'get_hold', 'come_up', 'find'], ['discover', 'find'], ['discover', 'find'], ['discover', 'find'], ['discover', 'find'], ['find'], ['rule', 'find'], ['rule', 'find'], ['receive', 'get', 'find', 'obtain', 'incur'], ['receive', 'get', 'find', 'obtain', 'incur'], ['receive', 'get', 'find', 'obtain', 'incur'], ['receive', 'get', 'find', 'obtain', 'incur'], ['receive', 'get', 'find', 'obtain', 'incur'], ['find'], ['recover', 'retrieve', 'find', 'regain'], ['recover', 'retrieve', 'find', 'regain'], ['recover', 'retrieve', 'find', 'regain'], ['recover', 'retrieve', 'find', 'regain'], ['find'], ['find_oneself', 'find'], ['find_oneself', 'find'], ['found']]}, {'hypernyms': [['open', 'open_up'], ['establish', 'set_up', 'found', 'launch']]})}
# The symonyms and hypernyms for: {'donor': ({'symonyms': [['donor', 'giver', 'presenter', 'bestower', 'conferrer'], ['donor', 'giver', 'presenter', 'bestower', 'conferrer'], ['donor', 'giver', 'presenter', 'bestower', 'conferrer'], ['donor', 'giver', 'presenter', 'bestower', 'conferrer'], ['donor', 'giver', 'presenter', 'bestower', 'conferrer'], ['donor']]}, {'hypernyms': [['entity'], ['physical_entity'], ['causal_agent', 'cause', 'causal_agency'], ['person', 'individual', 'someone', 'somebody', 'mortal', 'soul'], ['good_person'], ['benefactor', 'helper'], ['donor']]})}
# The symonyms and hypernyms for: {'willing': ({'symonyms': [['volition', 'willing'], ['volition', 'willing'], ['will'], ['will'], ['bequeath', 'will', 'leave'], ['bequeath', 'will', 'leave'], ['bequeath', 'will', 'leave'], ['willing'], ['uncoerced', 'unforced', 'willing'], ['uncoerced', 'unforced', 'willing'], ['uncoerced', 'unforced', 'willing']]}, {'hypernyms': [['express', 'verbalize', 'verbalise', 'utter', 'give_tongue_to'], ['state', 'say', 'tell'], ['declare'], ['decree'], ['ordain'], ['will']]})}
# The symonyms and hypernyms for: {'portion': ({'symonyms': [['part', 'portion', 'component_part', 'component', 'constituent'], ['part', 'portion', 'component_part', 'component', 'constituent'], ['part', 'portion', 'component_part', 'component', 'constituent'], ['part', 'portion', 'component_part', 'component', 'constituent'], ['part', 'portion', 'component_part', 'component', 'constituent'], ['part', 'portion'], ['part', 'portion'], ['parcel', 'portion', 'share'], ['parcel', 'portion', 'share'], ['parcel', 'portion', 'share'], ['share', 'portion', 'part', 'percentage'], ['share', 'portion', 'part', 'percentage'], ['share', 'portion', 'part', 'percentage'], ['share', 'portion', 'part', 'percentage'], ['fortune', 'destiny', 'fate', 'luck', 'lot', 'circumstances', 'portion'], ['fortune', 'destiny', 'fate', 'luck', 'lot', 'circumstances', 'portion'], ['fortune', 'destiny', 'fate', 'luck', 'lot', 'circumstances', 'portion'], ['fortune', 'destiny', 'fate', 'luck', 'lot', 'circumstances', 'portion'], ['fortune', 'destiny', 'fate', 'luck', 'lot', 'circumstances', 'portion'], ['fortune', 'destiny', 'fate', 'luck', 'lot', 'circumstances', 'portion'], ['fortune', 'destiny', 'fate', 'luck', 'lot', 'circumstances', 'portion'], ['dowry', 'dowery', 'dower', 'portion'], ['dowry', 'dowery', 'dower', 'portion'], ['dowry', 'dowery', 'dower', 'portion'], ['dowry', 'dowery', 'dower', 'portion'], ['helping', 'portion', 'serving'], ['helping', 'portion', 'serving'], ['helping', 'portion', 'serving'], ['assign', 'allot', 'portion'], ['assign', 'allot', 'portion'], ['assign', 'allot', 'portion']]}, {'hypernyms': [['entity'], ['physical_entity'], ['object', 'physical_object'], ['part', 'portion']]})}
# The symonyms and hypernyms for: {'tissue': ({'symonyms': [['tissue'], ['tissue', 'tissue_paper'], ['tissue', 'tissue_paper'], ['weave', 'tissue'], ['weave', 'tissue']]}, {'hypernyms': [['entity'], ['physical_entity'], ['matter'], ['substance'], ['material', 'stuff'], ['paper'], ['tissue', 'tissue_paper']]})}
# The symonyms and hypernyms for: {'reason': ({'symonyms': [['reason', 'ground'], ['reason', 'ground'], ['reason'], ['reason', 'understanding', 'intellect'], ['reason', 'understanding', 'intellect'], ['reason', 'understanding', 'intellect'], ['rationality', 'reason', 'reasonableness'], ['rationality', 'reason', 'reasonableness'], ['rationality', 'reason', 'reasonableness'], ['cause', 'reason', 'grounds'], ['cause', 'reason', 'grounds'], ['cause', 'reason', 'grounds'], ['reason'], ['reason', 'reason_out', 'conclude'], ['reason', 'reason_out', 'conclude'], ['reason', 'reason_out', 'conclude'], ['argue', 'reason'], ['argue', 'reason'], ['reason']]}, {'hypernyms': [['entity'], ['abstraction', 'abstract_entity'], ['communication'], ['message', 'content', 'subject_matter', 'substance'], ['statement'], ['explanation', 'account'], ['reason']]})}
# The symonyms and hypernyms for: {'recipient': ({'symonyms': [['recipient', 'receiver'], ['recipient', 'receiver'], ['recipient_role', 'recipient'], ['recipient_role', 'recipient']]}, {'hypernyms': [['entity'], ['abstraction', 'abstract_entity'], ['group', 'grouping'], ['collection', 'aggregation', 'accumulation', 'assemblage'], ['class', 'category', 'family'], ['grammatical_category', 'syntactic_category'], ['semantic_role', 'participant_role'], ['recipient_role', 'recipient']]})}
# The symonyms and hypernyms for: {'wa': ({'symonyms': []}, {'hypernyms': []})}
# The symonyms and hypernyms for: {'ready': ({'symonyms': [['ready'], ['cook', 'fix', 'ready', 'make', 'prepare'], ['cook', 'fix', 'ready', 'make', 'prepare'], ['cook', 'fix', 'ready', 'make', 'prepare'], ['cook', 'fix', 'ready', 'make', 'prepare'], ['cook', 'fix', 'ready', 'make', 'prepare'], ['fix', 'prepare', 'set_up', 'ready', 'gear_up', 'set'], ['fix', 'prepare', 'set_up', 'ready', 'gear_up', 'set'], ['fix', 'prepare', 'set_up', 'ready', 'gear_up', 'set'], ['fix', 'prepare', 'set_up', 'ready', 'gear_up', 'set'], ['fix', 'prepare', 'set_up', 'ready', 'gear_up', 'set'], ['fix', 'prepare', 'set_up', 'ready', 'gear_up', 'set'], ['ready'], ['ready'], ['ready'], ['ready'], ['quick', 'ready'], ['quick', 'ready']]}, {'hypernyms': [['make', 'create'], ['create_from_raw_material', 'create_from_raw_stuff'], ['cook', 'fix', 'ready', 'make', 'prepare']]})}
# The symonyms and hypernyms for: {'storage': ({'symonyms': [['storage'], ['storehouse', 'depot', 'entrepot', 'storage', 'store'], ['storehouse', 'depot', 'entrepot', 'storage', 'store'], ['storehouse', 'depot', 'entrepot', 'storage', 'store'], ['storehouse', 'depot', 'entrepot', 'storage', 'store'], ['storehouse', 'depot', 'entrepot', 'storage', 'store'], ['storage'], ['storage'], ['memory', 'computer_memory', 'storage', 'computer_storage', 'store', 'memory_board'], ['memory', 'computer_memory', 'storage', 'computer_storage', 'store', 'memory_board'], ['memory', 'computer_memory', 'storage', 'computer_storage', 'store', 'memory_board'], ['memory', 'computer_memory', 'storage', 'computer_storage', 'store', 'memory_board'], ['memory', 'computer_memory', 'storage', 'computer_storage', 'store', 'memory_board'], ['memory', 'computer_memory', 'storage', 'computer_storage', 'store', 'memory_board'], ['repositing', 'reposition', 'storage', 'warehousing'], ['repositing', 'reposition', 'storage', 'warehousing'], ['repositing', 'reposition', 'storage', 'warehousing'], ['repositing', 'reposition', 'storage', 'warehousing']]}, {'hypernyms': [['entity'], ['physical_entity'], ['object', 'physical_object'], ['whole', 'unit'], ['artifact', 'artefact'], ['facility', 'installation'], ['depository', 'deposit', 'depositary', 'repository'], ['storehouse', 'depot', 'entrepot', 'storage', 'store']]})}
# The symonyms and hypernyms for: {'necessary': ({'symonyms': [['necessity', 'essential', 'requirement', 'requisite', 'necessary'], ['necessity', 'essential', 'requirement', 'requisite', 'necessary'], ['necessity', 'essential', 'requirement', 'requisite', 'necessary'], ['necessity', 'essential', 'requirement', 'requisite', 'necessary'], ['necessity', 'essential', 'requirement', 'requisite', 'necessary'], ['necessary'], ['necessary']]}, {'hypernyms': [['necessary']]})}
# The symonyms and hypernyms for: {'material': ({'symonyms': [['material', 'stuff'], ['material', 'stuff'], ['material'], ['fabric', 'cloth', 'material', 'textile'], ['fabric', 'cloth', 'material', 'textile'], ['fabric', 'cloth', 'material', 'textile'], ['fabric', 'cloth', 'material', 'textile'], ['material'], ['material'], ['material'], ['material'], ['material'], ['material'], ['corporeal', 'material'], ['corporeal', 'material'], ['substantial', 'real', 'material'], ['substantial', 'real', 'material'], ['substantial', 'real', 'material']]}, {'hypernyms': [['entity'], ['abstraction', 'abstract_entity'], ['communication'], ['message', 'content', 'subject_matter', 'substance'], ['information', 'info'], ['material']]})}
# The symonyms and hypernyms for: {'saline': ({'symonyms': [['saline_solution', 'saline'], ['saline_solution', 'saline'], ['saline']]}, {'hypernyms': [['saline']]})}
# The symonyms and hypernyms for: {'period': ({'symonyms': [['time_period', 'period_of_time', 'period'], ['time_period', 'period_of_time', 'period'], ['time_period', 'period_of_time', 'period'], ['period'], ['period'], ['period', 'geological_period'], ['period', 'geological_period'], ['period'], ['menstruation', 'menses', 'menstruum', 'catamenia', 'period', 'flow'], ['menstruation', 'menses', 'menstruum', 'catamenia', 'period', 'flow'], ['menstruation', 'menses', 'menstruum', 'catamenia', 'period', 'flow'], ['menstruation', 'menses', 'menstruum', 'catamenia', 'period', 'flow'], ['menstruation', 'menses', 'menstruum', 'catamenia', 'period', 'flow'], ['menstruation', 'menses', 'menstruum', 'catamenia', 'period', 'flow'], ['period', 'point', 'full_stop', 'stop', 'full_point'], ['period', 'point', 'full_stop', 'stop', 'full_point'], ['period', 'point', 'full_stop', 'stop', 'full_point'], ['period', 'point', 'full_stop', 'stop', 'full_point'], ['period', 'point', 'full_stop', 'stop', 'full_point']]}, {'hypernyms': [['entity'], ['abstraction', 'abstract_entity'], ['measure', 'quantity', 'amount'], ['time_interval', 'interval'], ['period']]})}
# The symonyms and hypernyms for: {'reintroduction': ({'symonyms': []}, {'hypernyms': []})}
# The symonyms and hypernyms for: {'cavity': ({'symonyms': [['pit', 'cavity'], ['pit', 'cavity'], ['cavity', 'enclosed_space'], ['cavity', 'enclosed_space'], ['cavity', 'caries', 'dental_caries', 'tooth_decay'], ['cavity', 'caries', 'dental_caries', 'tooth_decay'], ['cavity', 'caries', 'dental_caries', 'tooth_decay'], ['cavity', 'caries', 'dental_caries', 'tooth_decay'], ['cavity', 'bodily_cavity', 'cavum'], ['cavity', 'bodily_cavity', 'cavum'], ['cavity', 'bodily_cavity', 'cavum']]}, {'hypernyms': [['entity'], ['abstraction', 'abstract_entity'], ['attribute'], ['shape', 'form'], ['amorphous_shape'], ['space'], ['cavity', 'enclosed_space']]})}
# The symonyms and hypernyms for: {'article': ({'symonyms': [['article'], ['article'], ['article', 'clause'], ['article', 'clause'], ['article'], ['article']]}, {'hypernyms': [['entity'], ['physical_entity'], ['object', 'physical_object'], ['whole', 'unit'], ['artifact', 'artefact'], ['article']]})}
# The symonyms and hypernyms for: {'month': ({'symonyms': [['calendar_month', 'month'], ['calendar_month', 'month'], ['month']]}, {'hypernyms': [['entity'], ['abstraction', 'abstract_entity'], ['measure', 'quantity', 'amount'], ['time_unit', 'unit_of_time'], ['month']]})}
# The symonyms and hypernyms for: {'sign': ({'symonyms': [['sign', 'mark'], ['sign', 'mark'], ['sign'], ['signal', 'signaling', 'sign'], ['signal', 'signaling', 'sign'], ['signal', 'signaling', 'sign'], ['signboard', 'sign'], ['signboard', 'sign'], ['sign_of_the_zodiac', 'star_sign', 'sign', 'mansion', 'house', 'planetary_house'], ['sign_of_the_zodiac', 'star_sign', 'sign', 'mansion', 'house', 'planetary_house'], ['sign_of_the_zodiac', 'star_sign', 'sign', 'mansion', 'house', 'planetary_house'], ['sign_of_the_zodiac', 'star_sign', 'sign', 'mansion', 'house', 'planetary_house'], ['sign_of_the_zodiac', 'star_sign', 'sign', 'mansion', 'house', 'planetary_house'], ['sign_of_the_zodiac', 'star_sign', 'sign', 'mansion', 'house', 'planetary_house'], ['sign'], ['polarity', 'sign'], ['polarity', 'sign'], ['augury', 'sign', 'foretoken', 'preindication'], ['augury', 'sign', 'foretoken', 'preindication'], ['augury', 'sign', 'foretoken', 'preindication'], ['augury', 'sign', 'foretoken', 'preindication'], ['sign'], ['sign'], ['sign'], ['sign', 'subscribe'], ['sign', 'subscribe'], ['sign', 'ratify'], ['sign', 'ratify'], ['sign'], ['sign', 'contract', 'sign_on', 'sign_up'], ['sign', 'contract', 'sign_on', 'sign_up'], ['sign', 'contract', 'sign_on', 'sign_up'], ['sign', 'contract', 'sign_on', 'sign_up'], ['sign', 'signal', 'signalize', 'signalise'], ['sign', 'signal', 'signalize', 'signalise'], ['sign', 'signal', 'signalize', 'signalise'], ['sign', 'signal', 'signalize', 'signalise'], ['sign'], ['sign'], ['bless', 'sign'], ['bless', 'sign'], ['gestural', 'sign', 'signed', 'sign-language'], ['gestural', 'sign', 'signed', 'sign-language'], ['gestural', 'sign', 'signed', 'sign-language'], ['gestural', 'sign', 'signed', 'sign-language']]}, {'hypernyms': [['entity'], ['abstraction', 'abstract_entity'], ['communication'], ['sign']]})}
# The symonyms and hypernyms for: {'hopeful': ({'symonyms': [['aspirant', 'aspirer', 'hopeful', 'wannabe', 'wannabee'], ['aspirant', 'aspirer', 'hopeful', 'wannabe', 'wannabee'], ['aspirant', 'aspirer', 'hopeful', 'wannabe', 'wannabee'], ['aspirant', 'aspirer', 'hopeful', 'wannabe', 'wannabee'], ['aspirant', 'aspirer', 'hopeful', 'wannabe', 'wannabee'], ['hopeful'], ['bright', 'hopeful', 'promising'], ['bright', 'hopeful', 'promising'], ['bright', 'hopeful', 'promising']]}, {'hypernyms': [['hopeful']]})}
# The symonyms and hypernyms for: {'manner': ({'symonyms': [['manner', 'mode', 'style', 'way', 'fashion'], ['manner', 'mode', 'style', 'way', 'fashion'], ['manner', 'mode', 'style', 'way', 'fashion'], ['manner', 'mode', 'style', 'way', 'fashion'], ['manner', 'mode', 'style', 'way', 'fashion'], ['manner', 'personal_manner'], ['manner', 'personal_manner'], ['manner']]}, {'hypernyms': [['entity'], ['abstraction', 'abstract_entity'], ['attribute'], ['trait'], ['demeanor', 'demeanour', 'behavior', 'behaviour', 'conduct', 'deportment'], ['manner', 'personal_manner']]})}
# The symonyms and hypernyms for: {'three': ({'symonyms': [['three', '3', 'III', 'trio', 'threesome', 'tierce', 'leash', 'troika', 'triad', 'trine', 'trinity', 'ternary', 'ternion', 'triplet', 'tercet', 'terzetto', 'trey', 'deuce-ace'], ['three', '3', 'III', 'trio', 'threesome', 'tierce', 'leash', 'troika', 'triad', 'trine', 'trinity', 'ternary', 'ternion', 'triplet', 'tercet', 'terzetto', 'trey', 'deuce-ace'], ['three', '3', 'III', 'trio', 'threesome', 'tierce', 'leash', 'troika', 'triad', 'trine', 'trinity', 'ternary', 'ternion', 'triplet', 'tercet', 'terzetto', 'trey', 'deuce-ace'], ['three', '3', 'III', 'trio', 'threesome', 'tierce', 'leash', 'troika', 'triad', 'trine', 'trinity', 'ternary', 'ternion', 'triplet', 'tercet', 'terzetto', 'trey', 'deuce-ace'], ['three', '3', 'III', 'trio', 'threesome', 'tierce', 'leash', 'troika', 'triad', 'trine', 'trinity', 'ternary', 'ternion', 'triplet', 'tercet', 'terzetto', 'trey', 'deuce-ace'], ['three', '3', 'III', 'trio', 'threesome', 'tierce', 'leash', 'troika', 'triad', 'trine', 'trinity', 'ternary', 'ternion', 'triplet', 'tercet', 'terzetto', 'trey', 'deuce-ace'], ['three', '3', 'III', 'trio', 'threesome', 'tierce', 'leash', 'troika', 'triad', 'trine', 'trinity', 'ternary', 'ternion', 'triplet', 'tercet', 'terzetto', 'trey', 'deuce-ace'], ['three', '3', 'III', 'trio', 'threesome', 'tierce', 'leash', 'troika', 'triad', 'trine', 'trinity', 'ternary', 'ternion', 'triplet', 'tercet', 'terzetto', 'trey', 'deuce-ace'], ['three', '3', 'III', 'trio', 'threesome', 'tierce', 'leash', 'troika', 'triad', 'trine', 'trinity', 'ternary', 'ternion', 'triplet', 'tercet', 'terzetto', 'trey', 'deuce-ace'], ['three', '3', 'III', 'trio', 'threesome', 'tierce', 'leash', 'troika', 'triad', 'trine', 'trinity', 'ternary', 'ternion', 'triplet', 'tercet', 'terzetto', 'trey', 'deuce-ace'], ['three', '3', 'III', 'trio', 'threesome', 'tierce', 'leash', 'troika', 'triad', 'trine', 'trinity', 'ternary', 'ternion', 'triplet', 'tercet', 'terzetto', 'trey', 'deuce-ace'], ['three', '3', 'III', 'trio', 'threesome', 'tierce', 'leash', 'troika', 'triad', 'trine', 'trinity', 'ternary', 'ternion', 'triplet', 'tercet', 'terzetto', 'trey', 'deuce-ace'], ['three', '3', 'III', 'trio', 'threesome', 'tierce', 'leash', 'troika', 'triad', 'trine', 'trinity', 'ternary', 'ternion', 'triplet', 'tercet', 'terzetto', 'trey', 'deuce-ace'], ['three', '3', 'III', 'trio', 'threesome', 'tierce', 'leash', 'troika', 'triad', 'trine', 'trinity', 'ternary', 'ternion', 'triplet', 'tercet', 'terzetto', 'trey', 'deuce-ace'], ['three', '3', 'III', 'trio', 'threesome', 'tierce', 'leash', 'troika', 'triad', 'trine', 'trinity', 'ternary', 'ternion', 'triplet', 'tercet', 'terzetto', 'trey', 'deuce-ace'], ['three', '3', 'III', 'trio', 'threesome', 'tierce', 'leash', 'troika', 'triad', 'trine', 'trinity', 'ternary', 'ternion', 'triplet', 'tercet', 'terzetto', 'trey', 'deuce-ace'], ['three', '3', 'III', 'trio', 'threesome', 'tierce', 'leash', 'troika', 'triad', 'trine', 'trinity', 'ternary', 'ternion', 'triplet', 'tercet', 'terzetto', 'trey', 'deuce-ace'], ['three', '3', 'III', 'trio', 'threesome', 'tierce', 'leash', 'troika', 'triad', 'trine', 'trinity', 'ternary', 'ternion', 'triplet', 'tercet', 'terzetto', 'trey', 'deuce-ace'], ['trey', 'three'], ['trey', 'three'], ['three', '3', 'iii'], ['three', '3', 'iii'], ['three', '3', 'iii']]}, {'hypernyms': [['entity'], ['physical_entity'], ['matter'], ['substance'], ['material', 'stuff'], ['paper'], ['card'], ['playing_card'], ['trey', 'three']]})}
# The symonyms and hypernyms for: {'group': ({'symonyms': [['group', 'grouping'], ['group', 'grouping'], ['group', 'radical', 'chemical_group'], ['group', 'radical', 'chemical_group'], ['group', 'radical', 'chemical_group'], ['group', 'mathematical_group'], ['group', 'mathematical_group'], ['group'], ['group', 'aggroup'], ['group', 'aggroup']]}, {'hypernyms': [['entity'], ['physical_entity'], ['thing'], ['unit', 'building_block'], ['group', 'radical', 'chemical_group']]})}
# The symonyms and hypernyms for: {'male': ({'symonyms': [['male'], ['male', 'male_person'], ['male', 'male_person'], ['Male'], ['male'], ['male', 'manful', 'manlike', 'manly', 'virile'], ['male', 'manful', 'manlike', 'manly', 'virile'], ['male', 'manful', 'manlike', 'manly', 'virile'], ['male', 'manful', 'manlike', 'manly', 'virile'], ['male', 'manful', 'manlike', 'manly', 'virile'], ['male']]}, {'hypernyms': [['entity'], ['physical_entity'], ['causal_agent', 'cause', 'causal_agency'], ['person', 'individual', 'someone', 'somebody', 'mortal', 'soul'], ['male', 'male_person']]})}
# The symonyms and hypernyms for: {'subject': ({'symonyms': [['subject', 'topic', 'theme'], ['subject', 'topic', 'theme'], ['subject', 'topic', 'theme'], ['subject', 'content', 'depicted_object'], ['subject', 'content', 'depicted_object'], ['subject', 'content', 'depicted_object'], ['discipline', 'subject', 'subject_area', 'subject_field', 'field', 'field_of_study', 'study', 'bailiwick'], ['discipline', 'subject', 'subject_area', 'subject_field', 'field', 'field_of_study', 'study', 'bailiwick'], ['discipline', 'subject', 'subject_area', 'subject_field', 'field', 'field_of_study', 'study', 'bailiwick'], ['discipline', 'subject', 'subject_area', 'subject_field', 'field', 'field_of_study', 'study', 'bailiwick'], ['discipline', 'subject', 'subject_area', 'subject_field', 'field', 'field_of_study', 'study', 'bailiwick'], ['discipline', 'subject', 'subject_area', 'subject_field', 'field', 'field_of_study', 'study', 'bailiwick'], ['discipline', 'subject', 'subject_area', 'subject_field', 'field', 'field_of_study', 'study', 'bailiwick'], ['discipline', 'subject', 'subject_area', 'subject_field', 'field', 'field_of_study', 'study', 'bailiwick'], ['topic', 'subject', 'issue', 'matter'], ['topic', 'subject', 'issue', 'matter'], ['topic', 'subject', 'issue', 'matter'], ['topic', 'subject', 'issue', 'matter'], ['subject'], ['subject', 'case', 'guinea_pig'], ['subject', 'case', 'guinea_pig'], ['subject', 'case', 'guinea_pig'], ['national', 'subject'], ['national', 'subject'], ['subject'], ['subject'], ['subject'], ['subjugate', 'subject'], ['subjugate', 'subject'], ['submit', 'subject'], ['submit', 'subject'], ['capable', 'open', 'subject'], ['capable', 'open', 'subject'], ['capable', 'open', 'subject'], ['subject', 'dependent'], ['subject', 'dependent'], ['subject']]}, {'hypernyms': [['entity'], ['physical_entity'], ['thing'], ['subject', 'content', 'depicted_object']]})}
# The symonyms and hypernyms for: {'average': ({'symonyms': [['average', 'norm'], ['average', 'norm'], ['average'], ['average'], ['average', 'average_out'], ['average', 'average_out'], ['average'], ['average', 'average_out'], ['average', 'average_out'], ['average', 'mean'], ['average', 'mean'], ['average', 'ordinary'], ['average', 'ordinary'], ['average', 'fair', 'mediocre', 'middling'], ['average', 'fair', 'mediocre', 'middling'], ['average', 'fair', 'mediocre', 'middling'], ['average', 'fair', 'mediocre', 'middling'], ['average', 'intermediate', 'medium'], ['average', 'intermediate', 'medium'], ['average', 'intermediate', 'medium'], ['modal', 'average'], ['modal', 'average'], ['median', 'average'], ['median', 'average']]}, {'hypernyms': [['entity'], ['abstraction', 'abstract_entity'], ['relation'], ['magnitude_relation', 'quantitative_relation'], ['ratio'], ['average']]})}
# The symonyms and hypernyms for: {'fitness': ({'symonyms': [['fitness', 'fittingness'], ['fitness', 'fittingness'], ['fitness', 'physical_fitness'], ['fitness', 'physical_fitness'], ['seaworthiness', 'fitness'], ['seaworthiness', 'fitness'], ['fitness']]}, {'hypernyms': [['entity'], ['abstraction', 'abstract_entity'], ['attribute'], ['state'], ['condition', 'status'], ['physical_condition', 'physiological_state', 'physiological_condition'], ['good_health', 'healthiness'], ['condition', 'shape'], ['fitness', 'physical_fitness']]})}
# The symonyms and hypernyms for: {'n': ({'symonyms': [['nitrogen', 'N', 'atomic_number_7'], ['nitrogen', 'N', 'atomic_number_7'], ['nitrogen', 'N', 'atomic_number_7'], ['north', 'due_north', 'northward', 'N'], ['north', 'due_north', 'northward', 'N'], ['north', 'due_north', 'northward', 'N'], ['north', 'due_north', 'northward', 'N'], ['newton', 'N'], ['newton', 'N'], ['normality', 'N'], ['normality', 'N'], ['N', 'n'], ['N', 'n']]}, {'hypernyms': [['entity'], ['abstraction', 'abstract_entity'], ['relation'], ['position', 'spatial_relation'], ['direction'], ['compass_point', 'point'], ['cardinal_compass_point'], ['north', 'due_north', 'northward', 'N']]})}
# The symonyms and hypernyms for: {'high': ({'symonyms': [['high'], ['high'], ['high'], ['high'], ['high', 'heights'], ['high', 'heights'], ['senior_high_school', 'senior_high', 'high', 'highschool', 'high_school'], ['senior_high_school', 'senior_high', 'high', 'highschool', 'high_school'], ['senior_high_school', 'senior_high', 'high', 'highschool', 'high_school'], ['senior_high_school', 'senior_high', 'high', 'highschool', 'high_school'], ['senior_high_school', 'senior_high', 'high', 'highschool', 'high_school'], ['high_gear', 'high'], ['high_gear', 'high'], ['high'], ['high'], ['eminent', 'high'], ['eminent', 'high'], ['high', 'high-pitched'], ['high', 'high-pitched'], ['high', 'in_high_spirits'], ['high', 'in_high_spirits'], ['gamey', 'gamy', 'high'], ['gamey', 'gamy', 'high'], ['gamey', 'gamy', 'high'], ['high', 'mellow'], ['high', 'mellow'], ['high', 'high_up'], ['high', 'high_up'], ['high'], ['high', 'richly', 'luxuriously'], ['high', 'richly', 'luxuriously'], ['high', 'richly', 'luxuriously'], ['high']]}, {'hypernyms': [['entity'], ['physical_entity'], ['process', 'physical_process'], ['phenomenon'], ['natural_phenomenon'], ['physical_phenomenon'], ['atmospheric_phenomenon'], ['weather', 'weather_condition', 'conditions', 'atmospheric_condition'], ['atmosphere', 'atmospheric_state'], ['air_mass'], ['high']]})}
# The symonyms and hypernyms for: {'hf': ({'symonyms': [['hafnium', 'Hf', 'atomic_number_72'], ['hafnium', 'Hf', 'atomic_number_72'], ['hafnium', 'Hf', 'atomic_number_72'], ['high_frequency', 'HF'], ['high_frequency', 'HF']]}, {'hypernyms': [['entity'], ['abstraction', 'abstract_entity'], ['relation'], ['magnitude_relation', 'quantitative_relation'], ['rate'], ['frequency', 'frequence', 'oftenness'], ['radio_frequency'], ['high_frequency', 'HF']]})}
# The symonyms and hypernyms for: {'fit': ({'symonyms': [['fit', 'tantrum', 'scene', 'conniption'], ['fit', 'tantrum', 'scene', 'conniption'], ['fit', 'tantrum', 'scene', 'conniption'], ['fit', 'tantrum', 'scene', 'conniption'], ['paroxysm', 'fit', 'convulsion'], ['paroxysm', 'fit', 'convulsion'], ['paroxysm', 'fit', 'convulsion'], ['fit'], ['burst', 'fit'], ['burst', 'fit'], ['suit', 'accommodate', 'fit'], ['suit', 'accommodate', 'fit'], ['suit', 'accommodate', 'fit'], ['fit', 'go'], ['fit', 'go'], ['meet', 'fit', 'conform_to'], ['meet', 'fit', 'conform_to'], ['meet', 'fit', 'conform_to'], ['fit'], ['fit'], ['match', 'fit', 'correspond', 'check', 'jibe', 'gibe', 'tally', 'agree'], ['match', 'fit', 'correspond', 'check', 'jibe', 'gibe', 'tally', 'agree'], ['match', 'fit', 'correspond', 'check', 'jibe', 'gibe', 'tally', 'agree'], ['match', 'fit', 'correspond', 'check', 'jibe', 'gibe', 'tally', 'agree'], ['match', 'fit', 'correspond', 'check', 'jibe', 'gibe', 'tally', 'agree'], ['match', 'fit', 'correspond', 'check', 'jibe', 'gibe', 'tally', 'agree'], ['match', 'fit', 'correspond', 'check', 'jibe', 'gibe', 'tally', 'agree'], ['match', 'fit', 'correspond', 'check', 'jibe', 'gibe', 'tally', 'agree'], ['fit'], ['equip', 'fit', 'fit_out', 'outfit'], ['equip', 'fit', 'fit_out', 'outfit'], ['equip', 'fit', 'fit_out', 'outfit'], ['equip', 'fit', 'fit_out', 'outfit'], ['match', 'fit'], ['match', 'fit'], ['fit'], ['fit', 'primed', 'set'], ['fit', 'primed', 'set'], ['fit', 'primed', 'set'], ['fit']]}, {'hypernyms': [['entity'], ['abstraction', 'abstract_entity'], ['psychological_feature'], ['event'], ['happening', 'occurrence', 'occurrent', 'natural_event'], ['trouble'], ['affliction'], ['attack'], ['paroxysm', 'fit', 'convulsion']]})}
# The symonyms and hypernyms for: {'race': ({'symonyms': [['race'], ['race'], ['race'], ['subspecies', 'race'], ['subspecies', 'race'], ['slipstream', 'airstream', 'race', 'backwash', 'wash'], ['slipstream', 'airstream', 'race', 'backwash', 'wash'], ['slipstream', 'airstream', 'race', 'backwash', 'wash'], ['slipstream', 'airstream', 'race', 'backwash', 'wash'], ['slipstream', 'airstream', 'race', 'backwash', 'wash'], ['raceway', 'race'], ['raceway', 'race'], ['rush', 'hotfoot', 'hasten', 'hie', 'speed', 'race', 'pelt_along', 'rush_along', 'cannonball_along', 'bucket_along', 'belt_along', 'step_on_it'], ['rush', 'hotfoot', 'hasten', 'hie', 'speed', 'race', 'pelt_along', 'rush_along', 'cannonball_along', 'bucket_along', 'belt_along', 'step_on_it'], ['rush', 'hotfoot', 'hasten', 'hie', 'speed', 'race', 'pelt_along', 'rush_along', 'cannonball_along', 'bucket_along', 'belt_along', 'step_on_it'], ['rush', 'hotfoot', 'hasten', 'hie', 'speed', 'race', 'pelt_along', 'rush_along', 'cannonball_along', 'bucket_along', 'belt_along', 'step_on_it'], ['rush', 'hotfoot', 'hasten', 'hie', 'speed', 'race', 'pelt_along', 'rush_along', 'cannonball_along', 'bucket_along', 'belt_along', 'step_on_it'], ['rush', 'hotfoot', 'hasten', 'hie', 'speed', 'race', 'pelt_along', 'rush_along', 'cannonball_along', 'bucket_along', 'belt_along', 'step_on_it'], ['rush', 'hotfoot', 'hasten', 'hie', 'speed', 'race', 'pelt_along', 'rush_along', 'cannonball_along', 'bucket_along', 'belt_along', 'step_on_it'], ['rush', 'hotfoot', 'hasten', 'hie', 'speed', 'race', 'pelt_along', 'rush_along', 'cannonball_along', 'bucket_along', 'belt_along', 'step_on_it'], ['rush', 'hotfoot', 'hasten', 'hie', 'speed', 'race', 'pelt_along', 'rush_along', 'cannonball_along', 'bucket_along', 'belt_along', 'step_on_it'], ['rush', 'hotfoot', 'hasten', 'hie', 'speed', 'race', 'pelt_along', 'rush_along', 'cannonball_along', 'bucket_along', 'belt_along', 'step_on_it'], ['rush', 'hotfoot', 'hasten', 'hie', 'speed', 'race', 'pelt_along', 'rush_along', 'cannonball_along', 'bucket_along', 'belt_along', 'step_on_it'], ['rush', 'hotfoot', 'hasten', 'hie', 'speed', 'race', 'pelt_along', 'rush_along', 'cannonball_along', 'bucket_along', 'belt_along', 'step_on_it'], ['race', 'run'], ['race', 'run'], ['race'], ['race', 'rush'], ['race', 'rush']]}, {'hypernyms': [['entity'], ['abstraction', 'abstract_entity'], ['psychological_feature'], ['event'], ['social_event'], ['contest', 'competition'], ['race']]})}
# The symonyms and hypernyms for: {'walker': ({'symonyms': [['Walker', 'John_Walker'], ['Walker', 'John_Walker'], ['Walker', 'Alice_Walker', 'Alice_Malsenior_Walker'], ['Walker', 'Alice_Walker', 'Alice_Malsenior_Walker'], ['Walker', 'Alice_Walker', 'Alice_Malsenior_Walker'], ['pedestrian', 'walker', 'footer'], ['pedestrian', 'walker', 'footer'], ['pedestrian', 'walker', 'footer'], ['walker'], ['walker', 'Zimmer', 'Zimmer_frame'], ['walker', 'Zimmer', 'Zimmer_frame'], ['walker', 'Zimmer', 'Zimmer_frame'], ['walker', 'baby-walker', 'go-cart'], ['walker', 'baby-walker', 'go-cart'], ['walker', 'baby-walker', 'go-cart']]}, {'hypernyms': [['entity'], ['physical_entity'], ['causal_agent', 'cause', 'causal_agency'], ['person', 'individual', 'someone', 'somebody', 'mortal', 'soul'], ['communicator'], ['writer', 'author'], ['Walker', 'Alice_Walker', 'Alice_Malsenior_Walker']]})}
# The symonyms and hypernyms for: {'treadmill': ({'symonyms': [['treadmill'], ['treadmill', 'treadwheel', 'tread-wheel'], ['treadmill', 'treadwheel', 'tread-wheel'], ['treadmill', 'treadwheel', 'tread-wheel'], ['treadmill', 'salt_mine'], ['treadmill', 'salt_mine']]}, {'hypernyms': [['entity'], ['physical_entity'], ['object', 'physical_object'], ['whole', 'unit'], ['artifact', 'artefact'], ['instrumentality', 'instrumentation'], ['device'], ['machine'], ['machinery'], ['mill', 'grinder', 'milling_machinery'], ['treadmill', 'treadwheel', 'tread-wheel']]})}
# The symonyms and hypernyms for: {'test': ({'symonyms': [['trial', 'trial_run', 'test', 'tryout'], ['trial', 'trial_run', 'test', 'tryout'], ['trial', 'trial_run', 'test', 'tryout'], ['trial', 'trial_run', 'test', 'tryout'], ['test', 'mental_test', 'mental_testing', 'psychometric_test'], ['test', 'mental_test', 'mental_testing', 'psychometric_test'], ['test', 'mental_test', 'mental_testing', 'psychometric_test'], ['test', 'mental_test', 'mental_testing', 'psychometric_test'], ['examination', 'exam', 'test'], ['examination', 'exam', 'test'], ['examination', 'exam', 'test'], ['test', 'trial'], ['test', 'trial'], ['test', 'trial', 'run'], ['test', 'trial', 'run'], ['test', 'trial', 'run'], ['test'], ['test', 'prove', 'try', 'try_out', 'examine', 'essay'], ['test', 'prove', 'try', 'try_out', 'examine', 'essay'], ['test', 'prove', 'try', 'try_out', 'examine', 'essay'], ['test', 'prove', 'try', 'try_out', 'examine', 'essay'], ['test', 'prove', 'try', 'try_out', 'examine', 'essay'], ['test', 'prove', 'try', 'try_out', 'examine', 'essay'], ['screen', 'test'], ['screen', 'test'], ['quiz', 'test'], ['quiz', 'test'], ['test'], ['test'], ['test'], ['test']]}, {'hypernyms': [['entity'], ['abstraction', 'abstract_entity'], ['psychological_feature'], ['event'], ['act', 'deed', 'human_action', 'human_activity'], ['activity'], ['measurement', 'measuring', 'measure', 'mensuration'], ['mental_measurement'], ['test', 'mental_test', 'mental_testing', 'psychometric_test']]})}
# The symonyms and hypernyms for: {'walking': ({'symonyms': [['walk', 'walking'], ['walk', 'walking'], ['walk'], ['walk'], ['walk'], ['walk'], ['walk'], ['walk'], ['walk'], ['walk'], ['walk'], ['walk', 'take_the_air'], ['walk', 'take_the_air'], ['walk-to', 'walking'], ['walk-to', 'walking']]}, {'hypernyms': [['travel', 'go', 'move', 'locomote'], ['walk']]})}
# The symonyms and hypernyms for: {'mph': ({'symonyms': [['miles_per_hour', 'mph'], ['miles_per_hour', 'mph'], ['miles_per_hour', 'mph'], ['miles_per_hour', 'mph']]}, {'hypernyms': [['entity'], ['abstraction', 'abstract_entity'], ['psychological_feature'], ['cognition', 'knowledge', 'noesis'], ['information'], ['datum', 'data_point'], ['reading', 'meter_reading', 'indication'], ['miles_per_hour', 'mph']]})}
# ...
# The symonyms and hypernyms for: {'yield': ({'symonyms': [['output', 'yield'], ['output', 'yield'], ['return', 'issue', 'take', 'takings', 'proceeds', 'yield', 'payoff'], ['return', 'issue', 'take', 'takings', 'proceeds', 'yield', 'payoff'], ['return', 'issue', 'take', 'takings', 'proceeds', 'yield', 'payoff'], ['return', 'issue', 'take', 'takings', 'proceeds', 'yield', 'payoff'], ['return', 'issue', 'take', 'takings', 'proceeds', 'yield', 'payoff'], ['return', 'issue', 'take', 'takings', 'proceeds', 'yield', 'payoff'], ['return', 'issue', 'take', 'takings', 'proceeds', 'yield', 'payoff'], ['yield', 'fruit'], ['yield', 'fruit'], ['output', 'yield', 'production'], ['output', 'yield', 'production'], ['output', 'yield', 'production'], ['yield', 'give', 'afford'], ['yield', 'give', 'afford'], ['yield', 'give', 'afford'], ['give_way', 'yield'], ['give_way', 'yield'], ['render', 'yield', 'return', 'give', 'generate'], ['render', 'yield', 'return', 'give', 'generate'], ['render', 'yield', 'return', 'give', 'generate'], ['render', 'yield', 'return', 'give', 'generate'], ['render', 'yield', 'return', 'give', 'generate'], ['concede', 'yield', 'cede', 'grant'], ['concede', 'yield', 'cede', 'grant'], ['concede', 'yield', 'cede', 'grant'], ['concede', 'yield', 'cede', 'grant'], ['yield', 'relent', 'soften'], ['yield', 'relent', 'soften'], ['yield', 'relent', 'soften'], ['move_over', 'give_way', 'give', 'ease_up', 'yield'], ['move_over', 'give_way', 'give', 'ease_up', 'yield'], ['move_over', 'give_way', 'give', 'ease_up', 'yield'], ['move_over', 'give_way', 'give', 'ease_up', 'yield'], ['move_over', 'give_way', 'give', 'ease_up', 'yield'], ['give', 'yield'], ['give', 'yield'], ['concede', 'yield', 'grant'], ['concede', 'yield', 'grant'], ['concede', 'yield', 'grant'], ['succumb', 'yield'], ['succumb', 'yield'], ['yield', 'pay', 'bear'], ['yield', 'pay', 'bear'], ['yield', 'pay', 'bear'], ['give', 'yield'], ['give', 'yield'], ['yield'], ['yield', 'give_in', 'succumb', 'knuckle_under', 'buckle_under'], ['yield', 'give_in', 'succumb', 'knuckle_under', 'buckle_under'], ['yield', 'give_in', 'succumb', 'knuckle_under', 'buckle_under'], ['yield', 'give_in', 'succumb', 'knuckle_under', 'buckle_under'], ['yield', 'give_in', 'succumb', 'knuckle_under', 'buckle_under']]}, {'hypernyms': [['entity'], ['abstraction', 'abstract_entity'], ['relation'], ['possession'], ['assets'], ['sum', 'sum_of_money', 'amount', 'amount_of_money'], ['gain'], ['financial_gain'], ['income'], ['return', 'issue', 'take', 'takings', 'proceeds', 'yield', 'payoff']]})}
# The symonyms and hypernyms for: {'average': ({'symonyms': [['average', 'norm'], ['average', 'norm'], ['average'], ['average'], ['average', 'average_out'], ['average', 'average_out'], ['average'], ['average', 'average_out'], ['average', 'average_out'], ['average', 'mean'], ['average', 'mean'], ['average', 'ordinary'], ['average', 'ordinary'], ['average', 'fair', 'mediocre', 'middling'], ['average', 'fair', 'mediocre', 'middling'], ['average', 'fair', 'mediocre', 'middling'], ['average', 'fair', 'mediocre', 'middling'], ['average', 'intermediate', 'medium'], ['average', 'intermediate', 'medium'], ['average', 'intermediate', 'medium'], ['modal', 'average'], ['modal', 'average'], ['median', 'average'], ['median', 'average']]}, {'hypernyms': [['entity'], ['abstraction', 'abstract_entity'], ['relation'], ['magnitude_relation', 'quantitative_relation'], ['ratio'], ['average']]})}
# The symonyms and hypernyms for: {'simple': ({'symonyms': [['simple'], ['simpleton', 'simple'], ['simpleton', 'simple'], ['simple'], ['elementary', 'simple', 'uncomplicated', 'unproblematic'], ['elementary', 'simple', 'uncomplicated', 'unproblematic'], ['elementary', 'simple', 'uncomplicated', 'unproblematic'], ['elementary', 'simple', 'uncomplicated', 'unproblematic'], ['bare', 'mere', 'simple'], ['bare', 'mere', 'simple'], ['bare', 'mere', 'simple'], ['childlike', 'wide-eyed', 'round-eyed', 'dewy-eyed', 'simple'], ['childlike', 'wide-eyed', 'round-eyed', 'dewy-eyed', 'simple'], ['childlike', 'wide-eyed', 'round-eyed', 'dewy-eyed', 'simple'], ['childlike', 'wide-eyed', 'round-eyed', 'dewy-eyed', 'simple'], ['childlike', 'wide-eyed', 'round-eyed', 'dewy-eyed', 'simple'], ['dim-witted', 'simple', 'simple-minded'], ['dim-witted', 'simple', 'simple-minded'], ['dim-witted', 'simple', 'simple-minded'], ['simple', 'unsubdivided'], ['simple', 'unsubdivided'], ['simple']]}, {'hypernyms': [['entity'], ['physical_entity'], ['causal_agent', 'cause', 'causal_agency'], ['person', 'individual', 'someone', 'somebody', 'mortal', 'soul'], ['simpleton', 'simple']]})}
# The symonyms and hypernyms for: {'yield': ({'symonyms': [['output', 'yield'], ['output', 'yield'], ['return', 'issue', 'take', 'takings', 'proceeds', 'yield', 'payoff'], ['return', 'issue', 'take', 'takings', 'proceeds', 'yield', 'payoff'], ['return', 'issue', 'take', 'takings', 'proceeds', 'yield', 'payoff'], ['return', 'issue', 'take', 'takings', 'proceeds', 'yield', 'payoff'], ['return', 'issue', 'take', 'takings', 'proceeds', 'yield', 'payoff'], ['return', 'issue', 'take', 'takings', 'proceeds', 'yield', 'payoff'], ['return', 'issue', 'take', 'takings', 'proceeds', 'yield', 'payoff'], ['yield', 'fruit'], ['yield', 'fruit'], ['output', 'yield', 'production'], ['output', 'yield', 'production'], ['output', 'yield', 'production'], ['yield', 'give', 'afford'], ['yield', 'give', 'afford'], ['yield', 'give', 'afford'], ['give_way', 'yield'], ['give_way', 'yield'], ['render', 'yield', 'return', 'give', 'generate'], ['render', 'yield', 'return', 'give', 'generate'], ['render', 'yield', 'return', 'give', 'generate'], ['render', 'yield', 'return', 'give', 'generate'], ['render', 'yield', 'return', 'give', 'generate'], ['concede', 'yield', 'cede', 'grant'], ['concede', 'yield', 'cede', 'grant'], ['concede', 'yield', 'cede', 'grant'], ['concede', 'yield', 'cede', 'grant'], ['yield', 'relent', 'soften'], ['yield', 'relent', 'soften'], ['yield', 'relent', 'soften'], ['move_over', 'give_way', 'give', 'ease_up', 'yield'], ['move_over', 'give_way', 'give', 'ease_up', 'yield'], ['move_over', 'give_way', 'give', 'ease_up', 'yield'], ['move_over', 'give_way', 'give', 'ease_up', 'yield'], ['move_over', 'give_way', 'give', 'ease_up', 'yield'], ['give', 'yield'], ['give', 'yield'], ['concede', 'yield', 'grant'], ['concede', 'yield', 'grant'], ['concede', 'yield', 'grant'], ['succumb', 'yield'], ['succumb', 'yield'], ['yield', 'pay', 'bear'], ['yield', 'pay', 'bear'], ['yield', 'pay', 'bear'], ['give', 'yield'], ['give', 'yield'], ['yield'], ['yield', 'give_in', 'succumb', 'knuckle_under', 'buckle_under'], ['yield', 'give_in', 'succumb', 'knuckle_under', 'buckle_under'], ['yield', 'give_in', 'succumb', 'knuckle_under', 'buckle_under'], ['yield', 'give_in', 'succumb', 'knuckle_under', 'buckle_under'], ['yield', 'give_in', 'succumb', 'knuckle_under', 'buckle_under']]}, {'hypernyms': [['entity'], ['abstraction', 'abstract_entity'], ['relation'], ['possession'], ['assets'], ['sum', 'sum_of_money', 'amount', 'amount_of_money'], ['gain'], ['financial_gain'], ['income'], ['return', 'issue', 'take', 'takings', 'proceeds', 'yield', 'payoff']]})}
# The symonyms and hypernyms for: {'fund': ({'symonyms': [['fund', 'monetary_fund'], ['fund', 'monetary_fund'], ['store', 'stock', 'fund'], ['store', 'stock', 'fund'], ['store', 'stock', 'fund'], ['investment_company', 'investment_trust', 'investment_firm', 'fund'], ['investment_company', 'investment_trust', 'investment_firm', 'fund'], ['investment_company', 'investment_trust', 'investment_firm', 'fund'], ['investment_company', 'investment_trust', 'investment_firm', 'fund'], ['fund'], ['fund'], ['fund'], ['fund'], ['fund'], ['fund']]}, {'hypernyms': [['entity'], ['abstraction', 'abstract_entity'], ['relation'], ['possession'], ['assets'], ['sum', 'sum_of_money', 'amount', 'amount_of_money'], ['gain'], ['financial_gain'], ['income'], ['net_income', 'net', 'net_profit', 'lucre', 'profit', 'profits', 'earnings'], ['accumulation'], ['store', 'stock', 'fund']]})}
# The symonyms and hypernyms for: {'wa': ({'symonyms': []}, {'hypernyms': []})}
# The symonyms and hypernyms for: {'simple': ({'symonyms': [['simple'], ['simpleton', 'simple'], ['simpleton', 'simple'], ['simple'], ['elementary', 'simple', 'uncomplicated', 'unproblematic'], ['elementary', 'simple', 'uncomplicated', 'unproblematic'], ['elementary', 'simple', 'uncomplicated', 'unproblematic'], ['elementary', 'simple', 'uncomplicated', 'unproblematic'], ['bare', 'mere', 'simple'], ['bare', 'mere', 'simple'], ['bare', 'mere', 'simple'], ['childlike', 'wide-eyed', 'round-eyed', 'dewy-eyed', 'simple'], ['childlike', 'wide-eyed', 'round-eyed', 'dewy-eyed', 'simple'], ['childlike', 'wide-eyed', 'round-eyed', 'dewy-eyed', 'simple'], ['childlike', 'wide-eyed', 'round-eyed', 'dewy-eyed', 'simple'], ['childlike', 'wide-eyed', 'round-eyed', 'dewy-eyed', 'simple'], ['dim-witted', 'simple', 'simple-minded'], ['dim-witted', 'simple', 'simple-minded'], ['dim-witted', 'simple', 'simple-minded'], ['simple', 'unsubdivided'], ['simple', 'unsubdivided'], ['simple']]}, {'hypernyms': [['entity'], ['physical_entity'], ['causal_agent', 'cause', 'causal_agency'], ['person', 'individual', 'someone', 'somebody', 'mortal', 'soul'], ['simpleton', 'simple']]})}
# The symonyms and hypernyms for: {'yield': ({'symonyms': [['output', 'yield'], ['output', 'yield'], ['return', 'issue', 'take', 'takings', 'proceeds', 'yield', 'payoff'], ['return', 'issue', 'take', 'takings', 'proceeds', 'yield', 'payoff'], ['return', 'issue', 'take', 'takings', 'proceeds', 'yield', 'payoff'], ['return', 'issue', 'take', 'takings', 'proceeds', 'yield', 'payoff'], ['return', 'issue', 'take', 'takings', 'proceeds', 'yield', 'payoff'], ['return', 'issue', 'take', 'takings', 'proceeds', 'yield', 'payoff'], ['return', 'issue', 'take', 'takings', 'proceeds', 'yield', 'payoff'], ['yield', 'fruit'], ['yield', 'fruit'], ['output', 'yield', 'production'], ['output', 'yield', 'production'], ['output', 'yield', 'production'], ['yield', 'give', 'afford'], ['yield', 'give', 'afford'], ['yield', 'give', 'afford'], ['give_way', 'yield'], ['give_way', 'yield'], ['render', 'yield', 'return', 'give', 'generate'], ['render', 'yield', 'return', 'give', 'generate'], ['render', 'yield', 'return', 'give', 'generate'], ['render', 'yield', 'return', 'give', 'generate'], ['render', 'yield', 'return', 'give', 'generate'], ['concede', 'yield', 'cede', 'grant'], ['concede', 'yield', 'cede', 'grant'], ['concede', 'yield', 'cede', 'grant'], ['concede', 'yield', 'cede', 'grant'], ['yield', 'relent', 'soften'], ['yield', 'relent', 'soften'], ['yield', 'relent', 'soften'], ['move_over', 'give_way', 'give', 'ease_up', 'yield'], ['move_over', 'give_way', 'give', 'ease_up', 'yield'], ['move_over', 'give_way', 'give', 'ease_up', 'yield'], ['move_over', 'give_way', 'give', 'ease_up', 'yield'], ['move_over', 'give_way', 'give', 'ease_up', 'yield'], ['give', 'yield'], ['give', 'yield'], ['concede', 'yield', 'grant'], ['concede', 'yield', 'grant'], ['concede', 'yield', 'grant'], ['succumb', 'yield'], ['succumb', 'yield'], ['yield', 'pay', 'bear'], ['yield', 'pay', 'bear'], ['yield', 'pay', 'bear'], ['give', 'yield'], ['give', 'yield'], ['yield'], ['yield', 'give_in', 'succumb', 'knuckle_under', 'buckle_under'], ['yield', 'give_in', 'succumb', 'knuckle_under', 'buckle_under'], ['yield', 'give_in', 'succumb', 'knuckle_under', 'buckle_under'], ['yield', 'give_in', 'succumb', 'knuckle_under', 'buckle_under'], ['yield', 'give_in', 'succumb', 'knuckle_under', 'buckle_under']]}, {'hypernyms': [['entity'], ['abstraction', 'abstract_entity'], ['relation'], ['possession'], ['assets'], ['sum', 'sum_of_money', 'amount', 'amount_of_money'], ['gain'], ['financial_gain'], ['income'], ['return', 'issue', 'take', 'takings', 'proceeds', 'yield', 'payoff']]})}
# The symonyms and hypernyms for: {'fell': ({'symonyms': [['hide', 'fell'], ['hide', 'fell'], ['fell', 'felled_seam'], ['fell', 'felled_seam'], ['fell'], ['fell', 'drop', 'strike_down', 'cut_down'], ['fell', 'drop', 'strike_down', 'cut_down'], ['fell', 'drop', 'strike_down', 'cut_down'], ['fell', 'drop', 'strike_down', 'cut_down'], ['fly', 'fell', 'vanish'], ['fly', 'fell', 'vanish'], ['fly', 'fell', 'vanish'], ['fell'], ['fall'], ['descend', 'fall', 'go_down', 'come_down'], ['descend', 'fall', 'go_down', 'come_down'], ['descend', 'fall', 'go_down', 'come_down'], ['descend', 'fall', 'go_down', 'come_down'], ['fall'], ['fall', 'come'], ['fall', 'come'], ['precipitate', 'come_down', 'fall'], ['precipitate', 'come_down', 'fall'], ['precipitate', 'come_down', 'fall'], ['fall'], ['fall'], ['fall', 'shine', 'strike'], ['fall', 'shine', 'strike'], ['fall', 'shine', 'strike'], ['fall'], ['fall'], ['decrease', 'diminish', 'lessen', 'fall'], ['decrease', 'diminish', 'lessen', 'fall'], ['decrease', 'diminish', 'lessen', 'fall'], ['decrease', 'diminish', 'lessen', 'fall'], ['fall'], ['fall'], ['fall'], ['fall'], ['fall'], ['fall'], ['fall'], ['accrue', 'fall'], ['accrue', 'fall'], ['fall', 'light'], ['fall', 'light'], ['fall', 'return', 'pass', 'devolve'], ['fall', 'return', 'pass', 'devolve'], ['fall', 'return', 'pass', 'devolve'], ['fall', 'return', 'pass', 'devolve'], ['fall'], ['fall', 'fall_down'], ['fall', 'fall_down'], ['fall'], ['hang', 'fall', 'flow'], ['hang', 'fall', 'flow'], ['hang', 'fall', 'flow'], ['fall'], ['fall'], ['fall'], ['fall'], ['fall'], ['fall'], ['fall', 'descend', 'settle'], ['fall', 'descend', 'settle'], ['fall', 'descend', 'settle'], ['barbarous', 'brutal', 'cruel', 'fell', 'roughshod', 'savage', 'vicious'], ['barbarous', 'brutal', 'cruel', 'fell', 'roughshod', 'savage', 'vicious'], ['barbarous', 'brutal', 'cruel', 'fell', 'roughshod', 'savage', 'vicious'], ['barbarous', 'brutal', 'cruel', 'fell', 'roughshod', 'savage', 'vicious'], ['barbarous', 'brutal', 'cruel', 'fell', 'roughshod', 'savage', 'vicious'], ['barbarous', 'brutal', 'cruel', 'fell', 'roughshod', 'savage', 'vicious'], ['barbarous', 'brutal', 'cruel', 'fell', 'roughshod', 'savage', 'vicious']]}, {'hypernyms': [['entity'], ['physical_entity'], ['object', 'physical_object'], ['whole', 'unit'], ['artifact', 'artefact'], ['instrumentality', 'instrumentation'], ['connection', 'connexion', 'connector', 'connecter', 'connective'], ['junction', 'conjunction'], ['joint'], ['seam'], ['fell', 'felled_seam']]})}
# The symonyms and hypernyms for: {'average': ({'symonyms': [['average', 'norm'], ['average', 'norm'], ['average'], ['average'], ['average', 'average_out'], ['average', 'average_out'], ['average'], ['average', 'average_out'], ['average', 'average_out'], ['average', 'mean'], ['average', 'mean'], ['average', 'ordinary'], ['average', 'ordinary'], ['average', 'fair', 'mediocre', 'middling'], ['average', 'fair', 'mediocre', 'middling'], ['average', 'fair', 'mediocre', 'middling'], ['average', 'fair', 'mediocre', 'middling'], ['average', 'intermediate', 'medium'], ['average', 'intermediate', 'medium'], ['average', 'intermediate', 'medium'], ['modal', 'average'], ['modal', 'average'], ['median', 'average'], ['median', 'average']]}, {'hypernyms': [['entity'], ['abstraction', 'abstract_entity'], ['relation'], ['magnitude_relation', 'quantitative_relation'], ['ratio'], ['average']]})}
# The symonyms and hypernyms for: {'compound': ({'symonyms': [['compound'], ['compound', 'chemical_compound'], ['compound', 'chemical_compound'], ['compound'], ['intensify', 'compound', 'heighten', 'deepen'], ['intensify', 'compound', 'heighten', 'deepen'], ['intensify', 'compound', 'heighten', 'deepen'], ['intensify', 'compound', 'heighten', 'deepen'], ['compound', 'combine'], ['compound', 'combine'], ['compound'], ['compound'], ['compound', 'combine'], ['compound', 'combine'], ['compound'], ['compound'], ['colonial', 'compound'], ['colonial', 'compound']]}, {'hypernyms': [['entity'], ['physical_entity'], ['matter'], ['substance'], ['material', 'stuff'], ['chemical', 'chemical_substance'], ['compound', 'chemical_compound']]})}

# %% [markdown]
# function to get the nouns of a document:iterate through each sentence in a document
#                                         iterate through each word in the sentence
#                                         add them to nouns array if a noun
#
# function to get hypernyms of a given noun:initialise hypernym array and makes sure it only includes words with hypernyms
#                                           hypernyms are put into a variable and are then extarcted and returned
#
# function to get symonyms of a given noun:initialises symonym set and gets the synset of a word
#                                          makes sure it only includes words with symonyms
#                                          symonym's names are put into a variable and returned
#
# pair a word with its symonyms:put symonyms and hypernyms into sets which are then combined
#                               syms and hypes added to set with a key being the word which is returned
#
# def getSymHyp(nouns):initialise new doc dictionary
#                      iterate through each word in the nouns array and get their symonyms and hypernyms
#                      put the word, symonyms and hypernyms into the pair function and add this to the newDoc variable
#                      return the completed newDoc
#
# def outputs(newDoc):
# fucntion to output a word and symonyms and hypernyms:iterate through each word in a doc and output its symonyms and hypernyms
#
# getnouns and output is the called for each collection

# %% [markdown]
# ## Question 2: Supervised Methods for WSD (25 marks)
# The objective of this question is to build and evaluate a word sense disambiguation (WSD) system for words with multiple senses.

# %% [markdown]
# a).  For each word occurring in the medline corpus (defined above), **write code** to find how many senses it has according to WordNet.  Print a list of the 10 most frequently occurring words with 2 senses (in this corpus). \[4 marks\]

# %%
#import counter library for later use
from collections import Counter

#function to extract  number of senses of a given word
def sensesPerWord(w):
    #variable = number of synsets e.g. length of synset list
    numSenses=len(wn.synsets(w))
    #return number of senses
    return numSenses

#fuction that finds the distribution of senses for every word in a list of sentences 
def twoSense(w):
    #initialise senses set
    w2Senses={}
    #iterate through each word
    for k in w.keys():
        #if they have two senses add it to the set
        if sensesPerWord(k)==2:
            w2Senses[k]=w[k]
    #return all words with 2 senses
    return w2Senses

#function that gives document frequently
def doc_freq(doclist):
    #df set is initialised
    df={}
    #iterate through each document in give list as well as each word in the doc 
    for doc in doclist:
        for w in doc.keys():
            #gives the frequency of an item in a doc
            df[w]=df.get(w,0)+1
    #doc freq var is returned
    return df

#function to get medlines top 10 with 2 senses
def Top10(col):
    #frequency of medline document
    freq=doc_freq(col)
    #variable given words with only two senses
    filteredDoc=twoSense(freq)
    #the top 10 most frequent words in the lsit are applied to the top 10 variable
    topTen=dict(Counter(filteredDoc).most_common(10))
    #top ten are printed through iteration
    i=1
    for k in topTen.keys():
        print("In place", i ,"with", topTen[k], "occurrences is:", k)
        i+=1
    
#top ten function called
Top10(bow_collections['medline'])
# Out:
# In place 1 with 10 occurrences is: membrane
# In place 2 with 7 occurrences is: temperature
# In place 3 with 7 occurrences is: molecular
# In place 4 with 6 occurrences is: uptake
# In place 5 with 6 occurrences is: data
# In place 6 with 6 occurrences is: molecule
# In place 7 with 5 occurrences is: may
# In place 8 with 5 occurrences is: amino
# In place 9 with 5 occurrences is: phenomenon
# In place 10 with 4 occurrences is: ratio

# %% [markdown]
# import counter library for later use
#
# def sensesPerWord(w):
# function to extract  number of senses of a given word:variable = number of synsets e.g. length of synset list which is returned
#
# def twoSense(w):
# function that finds the distribution of senses for every word in a list of sentences:
#                                                                     initialise senses set and iterate through each word
#                                                                     if they have two senses add it to the set and return it
#
# function that gives document frequently:iterate through each document in the given list as well as each word in the doc
#                                         give the frequency of an item in a doc and return it
# def Top10(col):
# function to get medlines top 10 with 2 senses:frequency of medline document is gotten
#                                               variable given words with only two senses
#                                               top ten are printed through iteration
#
# top ten function called

# %% [markdown]
# b). A *supervised* WSD algorithm derives model(s) from *sense-annotated corpus data* in order to predict senses of ambiguous words in un-annotated data.  Using the entire document as context, **implement** a supervised word sense disambiguation algorithm to determine the most likely sense of each occurrence of the 3 most frequently occuring words identified in part a). \[8 marks\]

# %%
#fucntion to take words that have been tagged to a sentence
def extract_tags(taggedsentence):
    #initialise array alist
    alist=[]
    #for every word in taggedsentence check if its a Tree adn if labels=Lemmas and whether it has 1 leaf
    for item in taggedsentence:
        if isinstance(item,nltk.tree.Tree):
            if isinstance(item.label(),nltk.corpus.reader.wordnet.Lemma) and len(item.leaves())==1:
                #if so add to the output list
                alist.append((item.leaves()[0].lower(),item.label().synset()))
    return alist
            
#apply extract_tags to all sentences
def extract_senses(fileid_list):
    sentences=[]
    #goes through each file in the list
    for fileid in fileid_list:
        #show which file is currently being processed
        print("Processing {}".format(fileid))
        #add all extracted tags to a sentence
        sentences+=[extract_tags(taggedsentence) for taggedsentence in semcor.tagged_sents(fileid,tag='sem')]
    return sentences

#check whether a string is in a given sentence
def contains(sentence,astring):
    #filters out any sentences that are empty
    if len(sentence)>0:
        #takes all words in from a sentence
        tokens,tags=zip(*sentence)
        #returns the string if it is in the sentence
        return astring in tokens
    else:
        return False

#get the synset label for the word from the sentence
def get_label(sentence,word):
    count=0
    label="none"
    #for every word in the sentence get the label and return true if you can
    for token,tag in sentence:
        if token==word:
            count+=1
            label=str(tag)
    if count !=1:
        pass
    return label

#select sentences containing words and make labelled data sets where sentences are represented using Bernouilli's event model
def get_word_data(sentences,word):
    selected_sentences=[sentence for sentence in trainingData if contains(sentence,word)]
    word_data=[({token:True for (token,tag) in sentence},get_label(sentence,word)) for sentence in selected_sentences] 
    return word_data

# %%
from nltk.corpus import semcor
#extact all senses from the files in semcor for use as training data
trainingData=extract_senses(semcor.fileids())
# Out:
# Processing brown1/tagfiles/br-a01.xml
# Processing brown1/tagfiles/br-a02.xml
# Processing brown1/tagfiles/br-a11.xml
# Processing brown1/tagfiles/br-a12.xml
# Processing brown1/tagfiles/br-a13.xml
# Processing brown1/tagfiles/br-a14.xml
# Processing brown1/tagfiles/br-a15.xml
# Processing brown1/tagfiles/br-b13.xml
# Processing brown1/tagfiles/br-b20.xml
# Processing brown1/tagfiles/br-c01.xml
# Processing brown1/tagfiles/br-c02.xml
# Processing brown1/tagfiles/br-c04.xml
# Processing brown1/tagfiles/br-d01.xml
# Processing brown1/tagfiles/br-d02.xml
# Processing brown1/tagfiles/br-d03.xml
# Processing brown1/tagfiles/br-d04.xml
# Processing brown1/tagfiles/br-e01.xml
# Processing brown1/tagfiles/br-e02.xml
# Processing brown1/tagfiles/br-e04.xml
# Processing brown1/tagfiles/br-e21.xml
# Processing brown1/tagfiles/br-e24.xml
# Processing brown1/tagfiles/br-e29.xml
# Processing brown1/tagfiles/br-f03.xml
# Processing brown1/tagfiles/br-f10.xml
# Processing brown1/tagfiles/br-f19.xml
# Processing brown1/tagfiles/br-f43.xml
# Processing brown1/tagfiles/br-g01.xml
# Processing brown1/tagfiles/br-g11.xml
# Processing brown1/tagfiles/br-g15.xml
# Processing brown1/tagfiles/br-h01.xml
# Processing brown1/tagfiles/br-j01.xml
# Processing brown1/tagfiles/br-j02.xml
# Processing brown1/tagfiles/br-j03.xml
# Processing brown1/tagfiles/br-j04.xml
# Processing brown1/tagfiles/br-j05.xml
# Processing brown1/tagfiles/br-j06.xml
# Processing brown1/tagfiles/br-j07.xml
# Processing brown1/tagfiles/br-j08.xml
# Processing brown1/tagfiles/br-j09.xml
# Processing brown1/tagfiles/br-j10.xml
# Processing brown1/tagfiles/br-j11.xml
# Processing brown1/tagfiles/br-j12.xml
# Processing brown1/tagfiles/br-j13.xml
# Processing brown1/tagfiles/br-j14.xml
# Processing brown1/tagfiles/br-j15.xml
# Processing brown1/tagfiles/br-j16.xml
# Processing brown1/tagfiles/br-j17.xml
# Processing brown1/tagfiles/br-j18.xml
# Processing brown1/tagfiles/br-j19.xml
# Processing brown1/tagfiles/br-j20.xml
# Processing brown1/tagfiles/br-j22.xml
# Processing brown1/tagfiles/br-j23.xml
# Processing brown1/tagfiles/br-j37.xml
# Processing brown1/tagfiles/br-j52.xml
# Processing brown1/tagfiles/br-j53.xml
# Processing brown1/tagfiles/br-j54.xml
# Processing brown1/tagfiles/br-j55.xml
# Processing brown1/tagfiles/br-j56.xml
# Processing brown1/tagfiles/br-j57.xml
# Processing brown1/tagfiles/br-j58.xml
# Processing brown1/tagfiles/br-j59.xml
# Processing brown1/tagfiles/br-j60.xml
# Processing brown1/tagfiles/br-j70.xml
# Processing brown1/tagfiles/br-k01.xml
# Processing brown1/tagfiles/br-k02.xml
# Processing brown1/tagfiles/br-k03.xml
# Processing brown1/tagfiles/br-k04.xml
# Processing brown1/tagfiles/br-k05.xml
# Processing brown1/tagfiles/br-k06.xml
# Processing brown1/tagfiles/br-k07.xml
# Processing brown1/tagfiles/br-k08.xml
# Processing brown1/tagfiles/br-k09.xml
# Processing brown1/tagfiles/br-k10.xml
# Processing brown1/tagfiles/br-k11.xml
# Processing brown1/tagfiles/br-k12.xml
# Processing brown1/tagfiles/br-k13.xml
# Processing brown1/tagfiles/br-k14.xml
# Processing brown1/tagfiles/br-k15.xml
# Processing brown1/tagfiles/br-k16.xml
# Processing brown1/tagfiles/br-k17.xml
# Processing brown1/tagfiles/br-k18.xml
# Processing brown1/tagfiles/br-k19.xml
# Processing brown1/tagfiles/br-k20.xml
# Processing brown1/tagfiles/br-k21.xml
# Processing brown1/tagfiles/br-k22.xml
# Processing brown1/tagfiles/br-k23.xml
# Processing brown1/tagfiles/br-k24.xml
# Processing brown1/tagfiles/br-k25.xml
# Processing brown1/tagfiles/br-k26.xml
# Processing brown1/tagfiles/br-k27.xml
# Processing brown1/tagfiles/br-k28.xml
# Processing brown1/tagfiles/br-k29.xml
# Processing brown1/tagfiles/br-l11.xml
# Processing brown1/tagfiles/br-l12.xml
# Processing brown1/tagfiles/br-m01.xml
# Processing brown1/tagfiles/br-m02.xml
# Processing brown1/tagfiles/br-n05.xml
# Processing brown1/tagfiles/br-p01.xml
# Processing brown1/tagfiles/br-r05.xml
# Processing brown1/tagfiles/br-r06.xml
# Processing brown1/tagfiles/br-r07.xml
# Processing brown1/tagfiles/br-r08.xml
# Processing brown1/tagfiles/br-r09.xml
# Processing brown2/tagfiles/br-e22.xml
# Processing brown2/tagfiles/br-e23.xml
# Processing brown2/tagfiles/br-e25.xml
# Processing brown2/tagfiles/br-e26.xml
# Processing brown2/tagfiles/br-e27.xml
# Processing brown2/tagfiles/br-e28.xml
# Processing brown2/tagfiles/br-e30.xml
# Processing brown2/tagfiles/br-e31.xml
# Processing brown2/tagfiles/br-f08.xml
# Processing brown2/tagfiles/br-f13.xml
# Processing brown2/tagfiles/br-f14.xml
# Processing brown2/tagfiles/br-f15.xml
# Processing brown2/tagfiles/br-f16.xml
# Processing brown2/tagfiles/br-f17.xml
# Processing brown2/tagfiles/br-f18.xml
# Processing brown2/tagfiles/br-f20.xml
# Processing brown2/tagfiles/br-f21.xml
# Processing brown2/tagfiles/br-f22.xml
# Processing brown2/tagfiles/br-f23.xml
# Processing brown2/tagfiles/br-f24.xml
# Processing brown2/tagfiles/br-f25.xml
# Processing brown2/tagfiles/br-f33.xml
# Processing brown2/tagfiles/br-f44.xml
# Processing brown2/tagfiles/br-g12.xml
# Processing brown2/tagfiles/br-g14.xml
# Processing brown2/tagfiles/br-g16.xml
# Processing brown2/tagfiles/br-g17.xml
# Processing brown2/tagfiles/br-g18.xml
# Processing brown2/tagfiles/br-g19.xml
# Processing brown2/tagfiles/br-g20.xml
# Processing brown2/tagfiles/br-g21.xml
# Processing brown2/tagfiles/br-g22.xml
# Processing brown2/tagfiles/br-g23.xml
# Processing brown2/tagfiles/br-g28.xml
# Processing brown2/tagfiles/br-g31.xml
# Processing brown2/tagfiles/br-g39.xml
# Processing brown2/tagfiles/br-g43.xml
# Processing brown2/tagfiles/br-g44.xml
# Processing brown2/tagfiles/br-h09.xml
# Processing brown2/tagfiles/br-h11.xml
# Processing brown2/tagfiles/br-h12.xml
# Processing brown2/tagfiles/br-h13.xml
# Processing brown2/tagfiles/br-h14.xml
# Processing brown2/tagfiles/br-h15.xml
# Processing brown2/tagfiles/br-h16.xml
# Processing brown2/tagfiles/br-h17.xml
# Processing brown2/tagfiles/br-h18.xml
# Processing brown2/tagfiles/br-h21.xml
# Processing brown2/tagfiles/br-h24.xml
# Processing brown2/tagfiles/br-j29.xml
# Processing brown2/tagfiles/br-j30.xml
# Processing brown2/tagfiles/br-j31.xml
# Processing brown2/tagfiles/br-j32.xml
# Processing brown2/tagfiles/br-j33.xml
# Processing brown2/tagfiles/br-j34.xml
# Processing brown2/tagfiles/br-j35.xml
# Processing brown2/tagfiles/br-j38.xml
# Processing brown2/tagfiles/br-j41.xml
# Processing brown2/tagfiles/br-j42.xml
# Processing brown2/tagfiles/br-l08.xml
# Processing brown2/tagfiles/br-l09.xml
# Processing brown2/tagfiles/br-l10.xml
# Processing brown2/tagfiles/br-l13.xml
# Processing brown2/tagfiles/br-l14.xml
# Processing brown2/tagfiles/br-l15.xml
# Processing brown2/tagfiles/br-l16.xml
# Processing brown2/tagfiles/br-l17.xml
# Processing brown2/tagfiles/br-l18.xml
# Processing brown2/tagfiles/br-n09.xml
# Processing brown2/tagfiles/br-n10.xml
# Processing brown2/tagfiles/br-n11.xml
# Processing brown2/tagfiles/br-n12.xml
# Processing brown2/tagfiles/br-n14.xml
# Processing brown2/tagfiles/br-n15.xml
# Processing brown2/tagfiles/br-n16.xml
# Processing brown2/tagfiles/br-n17.xml
# Processing brown2/tagfiles/br-n20.xml
# Processing brown2/tagfiles/br-p07.xml
# Processing brown2/tagfiles/br-p09.xml
# Processing brown2/tagfiles/br-p10.xml
# Processing brown2/tagfiles/br-p12.xml
# Processing brown2/tagfiles/br-p24.xml
# Processing brown2/tagfiles/br-r04.xml
# Processing brownv/tagfiles/br-a03.xml
# Processing brownv/tagfiles/br-a04.xml
# Processing brownv/tagfiles/br-a05.xml
# Processing brownv/tagfiles/br-a06.xml
# Processing brownv/tagfiles/br-a07.xml
# Processing brownv/tagfiles/br-a08.xml
# Processing brownv/tagfiles/br-a09.xml
# Processing brownv/tagfiles/br-a10.xml
# Processing brownv/tagfiles/br-a16.xml
# Processing brownv/tagfiles/br-a17.xml
# Processing brownv/tagfiles/br-a18.xml
# Processing brownv/tagfiles/br-a19.xml
# Processing brownv/tagfiles/br-a20.xml
# Processing brownv/tagfiles/br-a21.xml
# Processing brownv/tagfiles/br-a22.xml
# Processing brownv/tagfiles/br-a23.xml
# Processing brownv/tagfiles/br-a24.xml
# Processing brownv/tagfiles/br-a25.xml
# Processing brownv/tagfiles/br-a26.xml
# Processing brownv/tagfiles/br-a27.xml
# Processing brownv/tagfiles/br-a28.xml
# Processing brownv/tagfiles/br-a29.xml
# Processing brownv/tagfiles/br-a30.xml
# Processing brownv/tagfiles/br-a31.xml
# Processing brownv/tagfiles/br-a32.xml
# Processing brownv/tagfiles/br-a33.xml
# Processing brownv/tagfiles/br-a34.xml
# Processing brownv/tagfiles/br-a35.xml
# Processing brownv/tagfiles/br-a36.xml
# Processing brownv/tagfiles/br-a37.xml
# Processing brownv/tagfiles/br-a38.xml
# Processing brownv/tagfiles/br-a39.xml
# Processing brownv/tagfiles/br-a40.xml
# Processing brownv/tagfiles/br-a41.xml
# Processing brownv/tagfiles/br-a42.xml
# Processing brownv/tagfiles/br-a43.xml
# Processing brownv/tagfiles/br-a44.xml
# Processing brownv/tagfiles/br-b01.xml
# Processing brownv/tagfiles/br-b02.xml
# Processing brownv/tagfiles/br-b03.xml
# Processing brownv/tagfiles/br-b04.xml
# Processing brownv/tagfiles/br-b05.xml
# Processing brownv/tagfiles/br-b06.xml
# Processing brownv/tagfiles/br-b07.xml
# Processing brownv/tagfiles/br-b08.xml
# Processing brownv/tagfiles/br-b09.xml
# Processing brownv/tagfiles/br-b10.xml
# Processing brownv/tagfiles/br-b11.xml
# Processing brownv/tagfiles/br-b12.xml
# Processing brownv/tagfiles/br-b14.xml
# Processing brownv/tagfiles/br-b15.xml
# Processing brownv/tagfiles/br-b16.xml
# Processing brownv/tagfiles/br-b17.xml
# Processing brownv/tagfiles/br-b18.xml
# Processing brownv/tagfiles/br-b19.xml
# Processing brownv/tagfiles/br-b21.xml
# Processing brownv/tagfiles/br-b22.xml
# Processing brownv/tagfiles/br-b23.xml
# Processing brownv/tagfiles/br-b24.xml
# Processing brownv/tagfiles/br-b25.xml
# Processing brownv/tagfiles/br-b26.xml
# Processing brownv/tagfiles/br-b27.xml
# Processing brownv/tagfiles/br-c03.xml
# Processing brownv/tagfiles/br-c05.xml
# Processing brownv/tagfiles/br-c06.xml
# Processing brownv/tagfiles/br-c07.xml
# Processing brownv/tagfiles/br-c08.xml
# Processing brownv/tagfiles/br-c09.xml
# Processing brownv/tagfiles/br-c10.xml
# Processing brownv/tagfiles/br-c11.xml
# Processing brownv/tagfiles/br-c12.xml
# Processing brownv/tagfiles/br-c13.xml
# Processing brownv/tagfiles/br-c14.xml
# Processing brownv/tagfiles/br-c15.xml
# Processing brownv/tagfiles/br-c16.xml
# Processing brownv/tagfiles/br-c17.xml
# Processing brownv/tagfiles/br-d05.xml
# Processing brownv/tagfiles/br-d06.xml
# Processing brownv/tagfiles/br-d07.xml
# Processing brownv/tagfiles/br-d08.xml
# Processing brownv/tagfiles/br-d09.xml
# Processing brownv/tagfiles/br-d10.xml
# Processing brownv/tagfiles/br-d11.xml
# Processing brownv/tagfiles/br-d12.xml
# Processing brownv/tagfiles/br-d13.xml
# Processing brownv/tagfiles/br-d14.xml
# Processing brownv/tagfiles/br-d15.xml
# Processing brownv/tagfiles/br-d16.xml
# Processing brownv/tagfiles/br-d17.xml
# Processing brownv/tagfiles/br-e03.xml
# Processing brownv/tagfiles/br-e05.xml
# Processing brownv/tagfiles/br-e06.xml
# Processing brownv/tagfiles/br-e07.xml
# Processing brownv/tagfiles/br-e08.xml
# Processing brownv/tagfiles/br-e09.xml
# Processing brownv/tagfiles/br-e10.xml
# Processing brownv/tagfiles/br-e11.xml
# Processing brownv/tagfiles/br-e12.xml
# Processing brownv/tagfiles/br-e13.xml
# Processing brownv/tagfiles/br-e14.xml
# Processing brownv/tagfiles/br-e15.xml
# Processing brownv/tagfiles/br-e16.xml
# Processing brownv/tagfiles/br-e17.xml
# Processing brownv/tagfiles/br-e18.xml
# Processing brownv/tagfiles/br-e19.xml
# Processing brownv/tagfiles/br-e20.xml
# Processing brownv/tagfiles/br-f01.xml
# Processing brownv/tagfiles/br-f02.xml
# Processing brownv/tagfiles/br-f04.xml
# Processing brownv/tagfiles/br-f05.xml
# Processing brownv/tagfiles/br-f06.xml
# Processing brownv/tagfiles/br-f07.xml
# Processing brownv/tagfiles/br-f09.xml
# Processing brownv/tagfiles/br-f11.xml
# Processing brownv/tagfiles/br-f12.xml
# Processing brownv/tagfiles/br-g02.xml
# Processing brownv/tagfiles/br-g03.xml
# Processing brownv/tagfiles/br-g04.xml
# Processing brownv/tagfiles/br-g05.xml
# Processing brownv/tagfiles/br-g06.xml
# Processing brownv/tagfiles/br-g07.xml
# Processing brownv/tagfiles/br-g08.xml
# Processing brownv/tagfiles/br-g09.xml
# Processing brownv/tagfiles/br-g10.xml
# Processing brownv/tagfiles/br-g13.xml
# Processing brownv/tagfiles/br-h02.xml
# Processing brownv/tagfiles/br-h03.xml
# Processing brownv/tagfiles/br-h04.xml
# Processing brownv/tagfiles/br-h05.xml
# Processing brownv/tagfiles/br-h06.xml
# Processing brownv/tagfiles/br-h07.xml
# Processing brownv/tagfiles/br-h08.xml
# Processing brownv/tagfiles/br-h10.xml
# Processing brownv/tagfiles/br-j21.xml
# Processing brownv/tagfiles/br-j24.xml
# Processing brownv/tagfiles/br-j25.xml
# Processing brownv/tagfiles/br-j26.xml
# Processing brownv/tagfiles/br-j27.xml
# Processing brownv/tagfiles/br-j28.xml
# Processing brownv/tagfiles/br-l01.xml
# Processing brownv/tagfiles/br-l02.xml
# Processing brownv/tagfiles/br-l03.xml
# Processing brownv/tagfiles/br-l04.xml
# Processing brownv/tagfiles/br-l05.xml
# Processing brownv/tagfiles/br-l06.xml
# Processing brownv/tagfiles/br-l07.xml
# Processing brownv/tagfiles/br-m03.xml
# Processing brownv/tagfiles/br-m04.xml
# Processing brownv/tagfiles/br-m05.xml
# Processing brownv/tagfiles/br-m06.xml
# Processing brownv/tagfiles/br-n01.xml
# Processing brownv/tagfiles/br-n02.xml
# Processing brownv/tagfiles/br-n03.xml
# Processing brownv/tagfiles/br-n04.xml
# Processing brownv/tagfiles/br-n06.xml
# Processing brownv/tagfiles/br-n07.xml
# Processing brownv/tagfiles/br-n08.xml
# Processing brownv/tagfiles/br-p02.xml
# Processing brownv/tagfiles/br-p03.xml
# Processing brownv/tagfiles/br-p04.xml
# Processing brownv/tagfiles/br-p05.xml
# Processing brownv/tagfiles/br-p06.xml
# Processing brownv/tagfiles/br-p08.xml
# Processing brownv/tagfiles/br-r01.xml
# Processing brownv/tagfiles/br-r02.xml
# Processing brownv/tagfiles/br-r03.xml

# %%
#create training data from the top three frequent words and previous training data
memTrain=get_word_data(trainingData,'membrane')
tempTrain=get_word_data(trainingData,'temperature')
moleTrain=get_word_data(trainingData,'molecular')

from nltk.classify.naivebayes import NaiveBayesClassifier
#train classifier using the created testing data
memClassifier=NaiveBayesClassifier.train(memTrain)
tempClassifier=NaiveBayesClassifier.train(tempTrain)
moleClassifier=NaiveBayesClassifier.train(moleTrain)

# %%
for d in range(len(bow_collections['medline'])):
    memData+=memClassifier.classify(bow_collections['medline'][d])
for i in range(len(bow_collections['medline'])):
    tempData=tempClassifier.classify(bow_collections['medline'][i])
for x in range(len(bow_collections['medline'])):
    moleData=moleClassifier.classify(bow_collections['medline'][x])

# %%
print(memData)
print(tempData)
print(moleData)
print((wn.synsets('membrane')[1]).lemma_names())
print((wn.synsets('temperature')[1]).lemma_names())
print((wn.synsets('molecular')[1]).lemma_names())
# Out:
# Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01')Synset('membrane.n.01 ...
# Synset('temperature.n.02')
# Synset('molecular.a.01')
# ['membrane', 'tissue_layer']
# ['temperature']
# ['molecular']

# %% [markdown]
# def extract_tags(taggedsentence):
# function to take words that have been tagged to a sentence:initialise array alist
#                                                            For every word in taggedsentence check if its a Tree and if                                                                     labels=Lemmas and whether it has 1 leaf
#                                                            If so add to the output list
# def extract_senses(fileid_list):
# Apply extract_tags to all sentences, show which file is being processed, add all extracted tags to a sentence
#
# def contains(sentence,astring):
# Check whether a string is in a sentence, filter out empty sentences and take all words in from a sentence and return the string if it is in the sentence
#
# def get_label(sentence,word):
# Get the synset label for the word from the sentence, for every word in the sentence get the label and return true if you can
#
# def get_word_data(sentences,word):
# Select sentences containing words and make labelled data sets where sentences are represented using Bernouilli's event model, extract all senses from the files in semcor for use as training data, create training data from the top three frequent words and previous training data
#
# import NaiveBayesClassifier
# train classifier using the created testing data
# collect senses for each word
# print these senses

# %% [markdown]
# c). Evaluate the performance of your WSD system.  How accurate is it for each of the 3 words? **Comment** on the strengths and weaknesses of your WSD system.\[8 marks\]

# %% [markdown]
# My system is as accurate as it can be as it only returns a single value for membrane and one for temperature and molecular also, this is as when looking for senses by hand I get the exact same results as my WSD system. Due to this there is not much room to get more accurate answers for these three words. However, this is only due to each word being used on its own classifier in the WSD system. This is as the way it operates at the moment is that each word has its own classifier to find its own senses and each classifier is only trained with the extracted senses of that word. This means when that word is given it shall give the words senses back which were previously extracted. This can also be a weakness of my WSD system as it means each word must have its own classifier trained in order to function and find that words senses as using anonther words classifer would result in no senses being found.

# %% [markdown]
# d) How could you extend or improve your WSD system?  You are **not** expected to code any of these extensions or improvements, but your answer should give sufficient details to make it clear how they might be carried out in practice. \[5 marks\]

# %% [markdown]
# Train a single classifier with all of the words in the collections and all of their senses so it can reliably give the intended senses as it will have a larger more accurate set of training data to pull from. This is instead of the current training data which uses the data of a single word to help classify the classifier. This means the classifier would be more accurate with multiple words but may be less accurate with single words. Another way of improving my WSD system would be to incoporate the lesk algorithm or boot strapping into the WSD to improve the assignment of senses with words that have common meanings.

# %% [markdown]
# Use the code below to verify that the length of your submission does not exceed 2000 words.

# %%
##This code will word count all of the markdown cells in the notebook saved at filepath
##Running it before providing any answers shows that the questions have a word count of 1202

import io
from nbformat import current

filepath="a2.ipynb"
question_count=626

with io.open(filepath, 'r', encoding='utf-8') as f:
    nb = current.read(f, 'json')

word_count = 0
for cell in nb.worksheets[0].cells:
    if cell.cell_type == "markdown":
        word_count += len(cell['source'].replace('#', '').lstrip().split(' '))
print("Submission length is {}".format(word_count-question_count))
# Out:
# Submission length is 2430
